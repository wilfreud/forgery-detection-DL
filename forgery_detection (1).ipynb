# %%
from os import getcwd, listdir, path as ospath, walk as oswalk
import keras

# %%
import kagglehub

# %%
# Download latest version (CASIA)
path = kagglehub.dataset_download("divg07/casia-20-image-tampering-detection-dataset")
fqPath = ospath.join(getcwd(), path, 'CASIA2')
print(listdir(fqPath+"/Au"))
print(listdir(fqPath+"/Tp"))

# Download (CoMoFoD)
# comoPath = kagglehub.dataset_download("tusharchauhan1898/comofod")
# comoFqPath =  ospath.join(getcwd(), comoPath, 'CoMoFoD_small_v2')
# print(listdir(comoFqPath))
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/divg07/casia-20-image-tampering-detection-dataset?dataset_version_number=1...
#  29%|██▉       | 763M/2.56G [00:11<01:37, 19.9MB/s]

# %%
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetV2B0
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Conv2D, BatchNormalization, Multiply, Input
from tensorflow.keras.models import Model
import numpy as np
import os
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import roc_curve, auc

# %%
# Configuration
IMG_SIZE = 224
BATCH_SIZE = 32 #nombre d'images exécutées simultanément
EPOCHS = 20 #nombre de cycles
def create_similarity_branch():
    return tf.keras.Sequential([
        Conv2D(256, 3, padding='same', activation='relu'),
        BatchNormalization(),
        Conv2D(128, 3, padding='same', activation='relu'),
        BatchNormalization()
    ])

# %%
def create_model():
    # Input
    input_shape = (IMG_SIZE, IMG_SIZE, 3)
    inputs = Input(shape=input_shape)

    # Base EfficientNetB0
    base_model = EfficientNetV2B0(weights='imagenet', include_top=False, input_tensor=inputs)

    # Dégeler les couches
    for layer in base_model.layers:
        layer.trainable = True

    # Extraction des features
    features = base_model.output

    # Branche de similarité pour détecter les régions copiées-collées
    similarity_branch = create_similarity_branch()(features)

    # Attention mechanism pour focus sur les régions suspectes
    attention = Conv2D(1, 1, activation='sigmoid', name='attention_output')(similarity_branch)
    attended_features = Multiply()([similarity_branch, attention])

    # Branch principale
    x = GlobalAveragePooling2D()(attended_features)
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.3)(x)

    # Sortie principale uniquement
    predictions = Dense(1, activation='sigmoid', name='main_output')(x)

    model = Model(inputs=inputs, outputs=predictions)
    return model

# %%
def prepare_data(data_dir):
    datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        horizontal_flip=True,
        validation_split=0.2, #on va prendre 80% des données en entrainement et 20% des données pour les tests
        brightness_range=[0.8, 1.2],
        zoom_range=0.1,
        fill_mode='nearest'
    )

     # Ajout de transformations spécifiques pour le copier-coller
    # def copy_move_augmentation(image):
    #     if np.random.random() < 0.3:  # 30% de chance d'appliquer
    #         h, w = image.shape[:2]
    #         # Sélectionner une région aléatoire
    #         size = np.random.randint(h//8, h//4)
    #         x1 = np.random.randint(0, w - size)
    #         y1 = np.random.randint(0, h - size)
    #         # Copier et coller à un nouvel endroit
    #         x2 = np.random.randint(0, w - size)
    #         y2 = np.random.randint(0, h - size)
    #         region = image[y1:y1+size, x1:x1+size].copy()
    #         image[y2:y2+size, x2:x2+size] = region
    #     return image

    # datagen.preprocessing_function = copy_move_augmentation

    # Prendre les dossiers Au et Tp pour la BD Casia V2
    classes = ['Au', 'Tp']

    #Prendre les dossiers Ori et Faux pour la BD Comofod
    # classes = ['Ori', 'Faux']

    train_generator = datagen.flow_from_directory(
        data_dir,
        target_size=(IMG_SIZE, IMG_SIZE),
        batch_size=BATCH_SIZE,
        class_mode='binary',  # Classification binaire
        subset='training',
        classes=classes,
        shuffle=True

    )

    validation_generator = datagen.flow_from_directory(
        data_dir,
        target_size=(IMG_SIZE, IMG_SIZE),
        batch_size=BATCH_SIZE,
        class_mode='binary',
        subset='validation',
        classes=classes,
        shuffle=True

    )

    return train_generator, validation_generator

# %%
def train_model():
    model = create_model()

    # Compilation simplifiée avec une seule sortie
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
        loss='binary_crossentropy',
        metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
    )
    #Chemin BD Casia V2
    train_generator, validation_generator = prepare_data(fqPath)

    #Chemin BD Comofod
    # train_generator, validation_generator = prepare_data('C:/Users/PC 9/OneDrive/Documents/M2/Deep_Learning/datasetComofod')

    callbacks = [
        tf.keras.callbacks.EarlyStopping(
            monitor='val_accuracy',
            patience=5,
            restore_best_weights=True,
            mode='max'
        ),
        tf.keras.callbacks.ModelCheckpoint(
            'best_model.keras',
            save_best_only=True,
            monitor='val_accuracy',
            mode='max'
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=3,
            mode='min'
        )
    ]

    history = model.fit(
        train_generator,
        epochs=EPOCHS,
        validation_data=validation_generator,
        callbacks=callbacks,
        class_weight={
            0: 1.0,  # Authentique
            1: 1.5   # Falsifié
        }
    )

    return model, history

# %%
   # Visualisation des résultats
import matplotlib.pyplot as plt

    #Seuil de décision
def plot_roc_curve(y_true, y_pred_proba):
     # Calculer les points de la courbe ROC
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_proba)

     # Calculer l'AUC
    roc_auc = auc(fpr, tpr)

    # Trouver le seuil optimal
    optimal_idx = np.argmax(tpr - fpr)
    optimal_threshold = thresholds[optimal_idx]

    print(f"Seuil optimal basé sur ROC : {optimal_threshold:.2f}")
    return optimal_threshold

def predict_image(model, image_path, treshold):
    img = tf.keras.preprocessing.image.load_img(
        image_path, target_size=(IMG_SIZE, IMG_SIZE)
    )
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = img_array / 255.0
    img_array = np.expand_dims(img_array, axis=0)

    # Obtenir la prédiction
    prediction = model.predict(img_array)[0]

    # Obtenir la carte d'attention (il faut créer un modèle intermédiaire)
    attention_model = Model(inputs=model.input,
                          outputs=model.get_layer('attention_output').output)
    attention_map = attention_model.predict(img_array)

    # Seuil de décision
    is_fake = prediction > optimal_threshold

    print(f"\nRésultat de l'analyse pour {image_path}:")
    print(f"Score de falsification: {prediction[0]:.2%}")
    print(f"Verdict: {'Image FALSIFIEE' if is_fake else 'Image AUTHENTIQUE'}")

    return {
        'prediction': float(prediction[0]),
        'is_fake': bool(is_fake),
        'confidence': float(abs(0.5 - prediction[0]) * 2)
    }

# %%
def evaluate_model(model, test_generator):
        # Prédire les probabilités sur le jeu de test
        y_pred_proba = model.predict(test_generator)

        # Obtenir les vraies classes
        y_true = test_generator.classes

        # Tracer la courbe ROC et trouver le seuil optimal
        optimal_threshold = plot_roc_curve(y_true, y_pred_proba)

        # Convertir les probabilités en prédictions binaires avec le seuil optimal
        y_pred_binary = (y_pred_proba > optimal_threshold).astype(int)

        # Calculer et afficher les métriques
        from sklearn.metrics import classification_report, confusion_matrix

        print("\nRapport de Classification:")
        print(classification_report(y_true, y_pred_binary, target_names=['Authentique', 'Falsifiée']))

        print("\nMatrice de Confusion:")
        print(confusion_matrix(y_true, y_pred_binary))

        return optimal_threshold

# %%
if __name__ == "__main__":
        # Entraîner le modèle
        model, history = train_model()

        # Préparer le générateur de validation
        _, validation_generator = prepare_data(fqPath)
        # _, validation_generator = prepare_data('C:/Users/PC 9/OneDrive/Documents/M2/Deep_Learning/datasetComofod')

        # Évaluer le modèle et calculer le seuil optimal
        optimal_threshold = evaluate_model(model, validation_generator)

        print(f"Seuil optimal utilisé pour les prédictions : {optimal_threshold:.2f}")


        # Test sur quelques images
        # test_images = [
        #     fqPath
        #     # BD Casia V2
        #     #"C:/Users/PC 9/OneDrive/Documents/M2/Deep_Learning/dataset/Au/Au_ani_00004.jpg",
        #     #"C:/Users/PC 9/OneDrive/Documents/M2/Deep_Learning/dataset/Au/Au_ani_00001.jpg"
        #     #"C:/Users/PC 9/OneDrive/Documents/M2/Deep_Learning/dataset/Tp/Tp_D_CNN_M_N_ani00057_ani00055_11149.jpg"
        #     #"C:/Users/PC 9/OneDrive/Documents/M2/Deep_Learning/dataset/Tp/Tp_D_CNN_S_N_cha10117_nat10139_12166.jpg"
        #     #"C:/Users/PC 9/OneDrive/Documents/M2/Deep_Learning/dataset/Au/Au_ani_00015.jpg"
        #     #"C:/Users/PC 9/OneDrive/Documents/M2/Deep_Learning/dataset/Au/Au_ani_00029.jpg"
        #     #"C:/Users/PC 9/OneDrive/Documents/M2/Deep_Learning/dataset/Tp/Tp_D_CNN_M_N_ani00023_ani00024_10205.tif"
        #     #"C:/Users/PC 9/OneDrive/Documents/M2/Deep_Learning/dataset/Tp/Tp_S_NRN_S_N_txt00070_txt00070_11316.jpg"

        #     #BD Comofod
        #    #"C:/Users/PC 9/OneDrive/Documents/M2/Deep_Learning/datasetComofod/Ori/001_O.png"
        #     # "C:/Users/PC 9/OneDrive/Documents/M2/Deep_Learning/datasetComofod/Faux/001_F.png"
        # ]

        # for image_path in test_images:
        #     results = predict_image(model, image_path, optimal_threshold)

# %%
keras.saving.save_model(model, "v2.keras")
print("Modèle sauvegardé avec succès.")
# print(listdir())

# %% [markdown]
# # Test de performance

# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from tensorflow.keras.models import load_model
import tensorflow as tf
from skimage.feature import match_template

# %%
# Configuration globale
MODEL_PATH = "v2.keras"
IMG_SIZE = 224
OUTPUT_CSV = "results_comofod.csv"
OUTPUT_GRAPH_DIR = "graphs_comofod"
os.makedirs(OUTPUT_GRAPH_DIR, exist_ok=True)
print(os.listdir())
# Out:
# ['.config', 'graphs_comofod', 'v2.keras', 'drive', 'sample_data']

# %%
# Charger le modèle CNN
try:
    cnn_model = load_model(os.path.join(os.getcwd(), MODEL_PATH))
    print(f"Modèle CNN chargé depuis {MODEL_PATH}.")
except Exception as e:
    print(f"Erreur lors du chargement du modèle CNN : {e}")
    cnn_model = None
# Out:
# Erreur lors du chargement du modèle CNN : Bad magic number for file header

# %%
# Fonction pour détecter les falsifications (méthode traditionnelle)
def detect_forgery(image_path, rows=32, cols=32, similarity_threshold=0.85, forgery_threshold=15):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if image is None:
        print(f"Erreur : Impossible de charger l'image {image_path}")
        return None

    h, w = image.shape
    block_height = h // rows
    block_width = w // cols
    suspicious_areas_count = 0

    for i in range(rows):
        for j in range(cols):
            y_start = i * block_height
            y_end = min(y_start + block_height, h)
            x_start = j * block_width
            x_end = min(x_start + block_width, w)

            block = image[y_start:y_end, x_start:x_end]
            result = match_template(image, block)
            locations = np.where(result >= similarity_threshold)

            suspicious_areas_count += len(locations[0])

    return suspicious_areas_count >= forgery_threshold

# %%
# Fonction pour prédire avec CNN
def predict_with_cnn(image_path):
    if not cnn_model:
        raise Exception("Modèle CNN non chargé.")

    img = tf.keras.preprocessing.image.load_img(image_path, target_size=(IMG_SIZE, IMG_SIZE))
    img_array = tf.keras.preprocessing.image.img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)

    prediction = cnn_model.predict(img_array)[0][0]
    return prediction > 0.5, prediction

# %%
# Adjusted limit for each directory
LIMIT = 10

def evaluate_methods(authentic_dir, forgery_dir):
    results = []
    true_labels = []
    cnn_predictions = []
    traditional_predictions = []

    print(f"Authenticate files: {len(os.listdir(authentic_dir))}")
    print(f"Forgery files: {len(os.listdir(forgery_dir))}")

    # Counter to limit the number of processed images
    authentic_count = 0
    forgery_count = 0

    # Process authentic directory
    for file in os.listdir(authentic_dir):
        if authentic_count >= LIMIT:
            break

        image_path = os.path.join(authentic_dir, file)
        if not file.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
            continue

        true_labels.append(0)  # Label 0 for authentic

        # CNN method
        try:
            cnn_forged, cnn_score = predict_with_cnn(image_path)
        except Exception as e:
            print(f"Error in CNN for {image_path}: {e}")
            cnn_forged, cnn_score = None, None

        # Traditional method
        traditional_forged = detect_forgery(image_path)

        # Save results
        results.append({
            "Image": image_path,
            "True Label": "Authentique",
            "CNN Prediction": "Falsifiée" if cnn_forged else "Authentique",
            "CNN Score": cnn_score,
            "Traditional Prediction": "Falsifiée" if traditional_forged else "Authentique"
        })
        print("--> Saving authentic results...")

        cnn_predictions.append(int(cnn_forged))
        traditional_predictions.append(int(traditional_forged))
        authentic_count += 1

    # Process forgery directory
    for file in os.listdir(forgery_dir):
        if forgery_count >= LIMIT:
            break

        image_path = os.path.join(forgery_dir, file)
        if not file.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
            continue

        true_labels.append(1)  # Label 1 for forgery

        # CNN method
        try:
            cnn_forged, cnn_score = predict_with_cnn(image_path)
        except Exception as e:
            print(f"Error in CNN for {image_path}: {e}")
            cnn_forged, cnn_score = None, None

        # Traditional method
        traditional_forged = detect_forgery(image_path)

        # Save results
        results.append({
            "Image": image_path,
            "True Label": "Falsifiée",
            "CNN Prediction": "Falsifiée" if cnn_forged else "Authentique",
            "CNN Score": cnn_score,
            "Traditional Prediction": "Falsifiée" if traditional_forged else "Authentique"
        })
        print("--> Saving forgery results...")

        cnn_predictions.append(int(cnn_forged))
        traditional_predictions.append(int(traditional_forged))
        forgery_count += 1

    # Save results to CSV
    results_df = pd.DataFrame(results)
    results_df.to_csv(OUTPUT_CSV, index=False)
    print(f"Results saved to {OUTPUT_CSV}.")

    # Return data for metrics
    return true_labels, cnn_predictions, traditional_predictions

# %%
# Générer les graphiques
def generate_graphs(true_labels, cnn_predictions, cnn_scores, traditional_predictions):
    # Courbe ROC pour CNN
    fpr, tpr, thresholds = roc_curve(true_labels, cnn_scores)
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, color="darkorange", lw=2, label=f"Courbe ROC (AUC = {roc_auc:.2f})")
    plt.plot([0, 1], [0, 1], color="navy", linestyle="--")
    plt.xlabel("Taux de faux positifs (FPR)")
    plt.ylabel("Taux de vrais positifs (TPR)")
    plt.title("Courbe ROC - Méthode CNN")
    plt.legend(loc="lower right")
    plt.savefig(os.path.join(OUTPUT_GRAPH_DIR, "roc_cnn.png"))
    print(f"Graphique ROC sauvegardé dans {OUTPUT_GRAPH_DIR}/roc_cnn.png.")

    # Matrices de confusion
    cm_cnn = confusion_matrix(true_labels, cnn_predictions)
    cm_traditional = confusion_matrix(true_labels, traditional_predictions)

    plt.figure()
    plt.matshow(cm_cnn, cmap="Blues")
    plt.title("Matrice de confusion - Méthode CNN")
    plt.colorbar()
    plt.ylabel("Vraies classes")
    plt.xlabel("Prédictions")
    plt.savefig(os.path.join(OUTPUT_GRAPH_DIR, "confusion_matrix_cnn.png"))

    plt.figure()
    plt.matshow(cm_traditional, cmap="Blues")
    plt.title("Matrice de confusion - Méthode Traditionnelle")
    plt.colorbar()
    plt.ylabel("Vraies classes")
    plt.xlabel("Prédictions")
    plt.savefig(os.path.join(OUTPUT_GRAPH_DIR, "confusion_matrix_traditional.png"))
    print("Matrices de confusion sauvegardées.")

# %%
import kagglehub
import os
from os import path as ospath, listdir, getcwd
# Download (CoMoFoD)
comoPath = kagglehub.dataset_download("tusharchauhan1898/comofod")
comoFqPath =  ospath.join(getcwd(), comoPath, 'CoMoFoD_small_v2')
print(listdir(comoFqPath))
# Out:
# ['015_O_JC6.jpg', '170_F_BC3.png', '149_F_JC2.jpg', '135_O_CR3.png', '044_O_NA3.png', '078_O_CR2.png', '143_F_NA2.png', '127_F_JC2.jpg', '086_O_CR3.png', '133_O_JC3.jpg', '052_F_BC1.png', '165_F_JC4.jpg', '165_F_JC6.jpg', '181_O_JC9.jpg', '107_O_CA3.png', '171_O_JC4.jpg', '040_O_NA1.png', '146_O_IB1.png', '180_O_NA2.png', '128_O_CR1.png', '115_F_NA3.png', '124_O_JC1.jpg', '151_F_IB1.png', '138_F_BC1.png', '016_F_CR2.png', '059_O_IB1.png', '148_O_JC7.jpg', '158_F_BC2.png', '159_O_BC3.png', '013_O_JC3.jpg', '138_F_BC2.png', '027_F_JC4.jpg', '005_F_BC2.png', '038_O_JC8.jpg', '096_O_CR3.png', '187_F_JC9.jpg', '172_O_BC1.png', '027_O_JC6.jpg', '187_F_JC5.jpg', '183_F_JC8.jpg', '050_F_JC8.jpg', '114_F_JC5.jpg', '123_F_CR2.png', '040_O_JC7.jpg', '156_O_IB2.png', '162_B.png', '169_O_JC6.jpg', '032_F_NA3.png', '037_F_JC3.jpg', '076_O_JC7.jpg', '142_F_NA3.png', '052_F_NA1.png', '200_O_JC1.jpg', '167_F_IB2.png', '098_F_IB1.png', '191_O_NA1.png', '082_O_CR2.png', '123_O_JC9.jpg', '179_F_CR3.png', '189_F_CR2.png', '131_F_JC9.jpg', '153_O_CR1.png', '120_O_NA2.png', '075_F_JC9.jpg', '189_O_JC2.jpg', '164_F_BC1.png', '101_F.png', '099_O_CR1.png', '063_O_CA2.png', '116_O_JC6.jpg', '033_F_IB1.png', '075_F_BC2.png', '055_O_CA3.png', '087_O_JC4.jpg', '121_O_IB3.png', '128_F.png', '020_F_JC8.jpg', '117_F_IB1.png', '085_F_CA3.png', '181_F_JC7.jpg', '058_F_CR2.png', '192_F_BC2.png', '018_F_JC2.jpg', '122_F_CR1.png', '091_F_JC8.jpg', '144_F_IB2.png', '014_O_NA3.png', '067_B.png', '080_O_BC1.png', '137_O_JC8.jpg', '077_O_CR1.png', '152_O_CA1.png', '002_O_JC8.jpg', '112_O_CA3.png', '138_F_IB2.png', '057_O_CA1.png', '025_O_NA3.png', '189_M.png', '161_F_JC9.jpg', '170_F_JC6.jpg', '191_O_NA2.png', '185_O_CA2.png', '027_O_CR2.png', '027_O_JC1.jpg', '160_O_IB2.png', '091_F_JC2.jpg', '104_F_CA1.png', '181_O_NA2.png', '064_F_NA2.png', '132_O_JC8.jpg', '161_F_CR3.png', '140_F_JC9.jpg', '110_F_CA1.png', '091_F_IB3.png', '025_O_IB1.png', '054_O_BC3.png', '129_F_IB1.png', '063_O_BC1.png', '126_F_JC2.jpg', '010_F_CA2.png', '002_O_JC9.jpg', '006_M.png', '102_M.png', '098_F_CA3.png', '049_F.png', '079_O_JC2.jpg', '093_O_NA1.png', '157_O_JC1.jpg', '142_O_IB2.png', '054_O_JC2.jpg', '026_O_BC3.png', '148_O_JC3.jpg', '013_F_BC2.png', '069_O_JC9.jpg', '136_O_BC3.png', '181_F_CR3.png', '155_O_IB3.png', '045_O_CA3.png', '159_F_JC1.jpg', '087_F_CA2.png', '048_O_IB1.png', '040_O_JC5.jpg', '112_O_JC7.jpg', '084_O_NA3.png', '200_O_IB1.png', '130_O_IB3.png', '117_F_BC2.png', '146_O_BC3.png', '043_O_JC7.jpg', '013_F_JC7.jpg', '068_F_CR3.png', '025_O_CR2.png', '192_O_JC7.jpg', '047_O_CA1.png', '045_O_CR2.png', '174_O_CR2.png', '109_O_JC4.jpg', '004_B.png', '064_O_NA2.png', '016_O_JC5.jpg', '164_F_JC6.jpg', '127_F_JC9.jpg', '053_O_JC8.jpg', '057_F_BC1.png', '124_F_BC2.png', '009_O_BC1.png', '002_O_IB1.png', '044_O_JC9.jpg', '179_O_NA1.png', '047_O_JC2.jpg', '159_F_JC9.jpg', '032_F_CR2.png', '017_O_BC1.png', '130_F_JC6.jpg', '065_O_JC9.jpg', '063_F_CA1.png', '181_O_BC1.png', '063_F_JC3.jpg', '136_O_NA2.png', '083_F_CA3.png', '193_F_NA3.png', '117_B.png', '166_F_JC4.jpg', '063_O_BC3.png', '103_O_NA1.png', '196_F_JC7.jpg', '149_F_IB3.png', '134_O_CA3.png', '079_F_BC1.png', '010_F_JC3.jpg', '199_O_JC1.jpg', '074_O_JC6.jpg', '130_F_JC7.jpg', '106_F_NA1.png', '166_F_IB2.png', '041_F_CR1.png', '049_O_NA3.png', '033_M.png', '140_O_CA3.png', '110_F_JC7.jpg', '140_O_NA3.png', '012_O_CR3.png', '008_F_JC4.jpg', '015_O_JC8.jpg', '039_F_NA1.png', '074_F_CR3.png', '089_O_BC3.png', '189_F_NA1.png', '134_O_JC7.jpg', '058_F_JC9.jpg', '097_O_CA2.png', '116_O_CR3.png', '194_O_JC6.jpg', '153_F_BC3.png', '015_F_JC5.jpg', '056_O_JC6.jpg', '013_F_NA3.png', '001_B.png', '164_O_CR1.png', '067_O_JC1.jpg', '124_F_IB3.png', '180_F_CA3.png', '006_F_CA2.png', '164_O_JC4.jpg', '152_F.png', '044_F_BC3.png', '106_O_JC7.jpg', '010_F_JC2.jpg', '186_F_CA1.png', '009_O_IB1.png', '153_M.png', '110_F_IB3.png', '012_F_JC9.jpg', '068_F_IB1.png', '052_F_CR3.png', '192_F_CA2.png', '180_O_BC1.png', '177_O_IB3.png', '156_F_IB ...

# %%
import shutil

def organize_comofod_files(file_list, dataset_dir):
    """
    Organise les fichiers du dataset CoMoFoD en deux sous-dossiers : Ori/ et Faux/.

    Args:
        file_list (list): Liste des noms de fichiers à organiser.
        dataset_dir (str): Répertoire contenant les fichiers.

    Returns:
        None
    """
    # Créer les répertoires pour les classes
    ori_dir = os.path.join(dataset_dir, "Ori")
    faux_dir = os.path.join(dataset_dir, "Faux")
    os.makedirs(ori_dir, exist_ok=True)
    os.makedirs(faux_dir, exist_ok=True)

    # Parcourir les fichiers et les organiser
    for file_name in file_list:
        src_path = os.path.join(dataset_dir, file_name)

        # Vérifier si le fichier existe
        if not os.path.isfile(src_path):
            print(f"Fichier introuvable : {src_path}")
            continue

        # Déterminer la classe (Ori ou Faux)
        if "_F" in file_name or "F_" in file_name:
            dest_path = os.path.join(faux_dir, file_name)
        elif "_O" in file_name or "O_" in file_name:
            dest_path = os.path.join(ori_dir, file_name)
        else:
            print(f"Fichier ignoré (classe inconnue) : {file_name}")
            continue

        # Déplacer le fichier
        shutil.move(src_path, dest_path)
        print(f"Déplacé : {file_name} -> {'Faux' if '_F' in file_name else 'Ori'}")

# %%
organize_comofod_files(listdir(comoFqPath), comoFqPath)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Déplacé : 155_O_JC2.jpg -> Ori
# Déplacé : 089_F_JC1.jpg -> Faux
# Déplacé : 116_F_JC7.jpg -> Faux
# Déplacé : 109_F_JC9.jpg -> Faux
# Déplacé : 019_F_JC8.jpg -> Faux
# Déplacé : 014_O_JC1.jpg -> Ori
# Déplacé : 067_F_IB1.png -> Faux
# Déplacé : 018_F_JC4.jpg -> Faux
# Déplacé : 032_O_JC3.jpg -> Ori
# Déplacé : 190_F_IB2.png -> Faux
# Déplacé : 035_O_CA2.png -> Ori
# Déplacé : 139_F_JC4.jpg -> Faux
# Déplacé : 029_F_CA1.png -> Faux
# Déplacé : 171_F_NA3.png -> Faux
# Fichier ignoré (classe inconnue) : 107_M.png
# Déplacé : 159_F_IB1.png -> Faux
# Déplacé : 140_O_IB1.png -> Ori
# Déplacé : 106_F_JC3.jpg -> Faux
# Déplacé : 110_F_NA1.png -> Faux
# Déplacé : 138_F_CA2.png -> Faux
# Déplacé : 053_O_IB1.png -> Ori
# Déplacé : 111_O_IB2.png -> Ori
# Déplacé : 136_O_JC1.jpg -> Ori
# Déplacé : 085_O_NA2.png -> Ori
# Déplacé : 198_F.png -> Faux
# Déplacé : 029_O_JC6.jpg -> Ori
# Déplacé : 040_O_IB2.png -> Ori
# Déplacé : 191_F_BC3.png -> Faux
# Déplacé : 072_O_JC5.jpg -> Ori
# Déplacé : 075_O_JC8.jpg -> Ori
# Déplacé : 175_O_CR2.png -> Ori
# Déplacé : 163_O_NA3.png -> Ori
# Fichier ignoré (classe inconnue) : 166_M.png
# Déplacé : 033_O_BC1.png -> Ori
# Déplacé : 049_O_JC3.jpg -> Ori
# Déplacé : 174_O_NA1.png -> Ori
# Déplacé : 197_O_CR2.png -> Ori
# Déplacé : 116_F_CA3.png -> Faux
# Déplacé : 026_F_NA3.png -> Faux
# Déplacé : 006_O_JC8.jpg -> Ori
# Déplacé : 192_F_JC7.jpg -> Faux
# Déplacé : 059_O_JC9.jpg -> Ori
# Déplacé : 190_O.png -> Ori
# Déplacé : 122_O_BC2.png -> Ori
# Déplacé : 095_F_IB2.png -> Faux
# Déplacé : 115_F_CR3.png -> Faux
# Déplacé : 128_F_IB1.png -> Faux
# Déplacé : 061_F_JC7.jpg -> Faux
# Déplacé : 006_O_NA2.png -> Ori
# Déplacé : 024_F_CR1.png -> Faux
# Déplacé : 126_O_JC8.jpg -> Ori
# Déplacé : 180_F_JC2.jpg -> Faux
# Déplacé : 072_O_JC8.jpg -> Ori
# Déplacé : 036_O_JC1.jpg -> Ori
# Déplacé : 177_O_JC5.jpg -> Ori
# Déplacé : 182_F_BC3.png -> Faux
# Déplacé : 128_O_CA3.png -> Ori
# Déplacé : 088_F_CA1.png -> Faux
# Déplacé : 065_O_JC5.jpg -> Ori
# Déplacé : 025_F_JC7.jpg -> Faux
# Déplacé : 023_F_JC5.jpg -> Faux
# Déplacé : 145_F_CA3.png -> Faux
# Déplacé : 067_F_BC2.png -> Faux
# Déplacé : 078_F_JC9.jpg -> Faux
# Déplacé : 194_F_JC2.jpg -> Faux
# Déplacé : 015_O_CR3.png -> Ori
# Déplacé : 103_O_NA3.png -> Ori
# Déplacé : 198_F_CA2.png -> Faux
# Déplacé : 059_F_JC6.jpg -> Faux
# Déplacé : 128_F_JC2.jpg -> Faux
# Déplacé : 003_F.png -> Faux
# Déplacé : 176_O_CR1.png -> Ori
# Déplacé : 063_O_IB3.png -> Ori
# Déplacé : 080_O_JC2.jpg -> Ori
# Déplacé : 172_F_JC7.jpg -> Faux
# Déplacé : 058_F_JC1.jpg -> Faux
# Déplacé : 106_O_JC2.jpg -> Ori
# Déplacé : 183_F_CR1.png -> Faux
# Déplacé : 108_F_CA3.png -> Faux
# Déplacé : 147_O_CA3.png -> Ori
# Déplacé : 007_O_BC3.png -> Ori
# Déplacé : 088_F_JC6.jpg -> Faux
# Déplacé : 135_F_CR3.png -> Faux
# Déplacé : 153_F_CR3.png -> Faux
# Déplacé : 127_F_CA1.png -> Faux
# Déplacé : 200_F.png -> Faux
# Déplacé : 131_F_IB3.png -> Faux
# Déplacé : 196_O_CA1.png -> Ori
# Déplacé : 024_O_JC1.jpg -> Ori
# Déplacé : 113_F_JC8.jpg -> Faux
# Déplacé : 138_O_BC1.png -> Ori
# Déplacé : 162_O_CR2.png -> Ori
# Déplacé : 109_F_BC2.png -> Faux
# Déplacé : 156_O_CR3.png -> Ori
# Déplacé : 192_O_IB2.png -> Ori
# Déplacé : 036_F_BC2.png -> Faux
# Déplacé : 132_F_CR2.png -> Faux
# Déplacé : 055_F_JC2.jpg -> Faux
# Déplacé : 116_O_CA3.png -> Ori
# Déplacé : 145_F_CR1.png -> Faux
# Déplacé : 073_F_IB1.png -> Faux
# Déplacé : 121_F_JC9.jpg -> Faux
# Déplacé : 133_F_BC1.png -> Faux
# Déplacé : 076_F_CA3.png -> Faux
# Déplacé : 011_O_CA3.png -> Ori
# Déplacé : 086_O_NA3.png -> Ori
# Déplacé : 178_F_IB3.png -> Faux
# Déplacé : 064_F_NA3.png -> Faux
# Déplacé : 120_F_JC7.jpg -> Faux
# Déplacé : 002_F.png -> Faux
# Déplacé : 173_O_BC3.png -> Ori
# Déplacé : 043_F_CA1.png -> Faux
# Déplacé : 194_O_CR3.png -> Ori
# Déplacé : 105_O_CR2.png -> Ori
# Déplacé : 182_F_JC8.jpg -> Faux
# Déplacé : 159_O_JC3.jpg -> Ori
# Déplacé : 117_O_IB2.png -> Ori
# Déplacé : 112_O_CA1.png -> Ori
# Déplacé : 155_O_JC3.jpg -> Ori
# Déplacé : 152_O_JC5.jpg -> Ori
# Déplacé : 011_F_CR3.png -> Faux
# Déplacé : 016_F_NA2.png -> Faux
# Déplacé : 184_O_JC4.jpg -> Ori
# Déplacé : 134_O_CA2.png -> Ori
# Déplacé : 198_F_JC3.jpg -> Faux
# Déplacé : 079_F_IB2.png -> Faux
# Déplacé : 108_F_JC7.jpg -> Faux
# Déplacé : 169_F_JC8.jpg -> Faux
# Déplacé : 147_F_CR2.png -> Faux
# Déplacé : 065_F_NA2.png -> Faux
# Fichier ignoré (classe inconnue) : 097_M.png
# Déplacé : 145_O_IB3.png -> Ori
# Déplacé : 133_F_CR1.png -> Faux
# Déplacé : 200_F_IB2.png -> Faux
# Déplacé : 098_O.png -> Ori
# Déplacé : 025_F_JC5.jpg -> Faux
# Déplacé : 084_O_JC7.jpg -> Ori
# Déplacé : 186_F_CR2.png -> Faux
# Déplacé : 069_F_NA2.png -> Faux
# Déplacé : 115_F_CR1.png -> Faux
# Déplacé : 126_F_JC8.jpg -> Faux
# Déplacé : 176_F_IB2.png -> Faux
# Fichier ignoré (classe inconnue) : 075_B.png
# Déplacé : 127_O_CR2.png -> Ori
# Déplacé : 154_F_JC2.jpg -> Faux
# Déplacé : 014_F_CA2.png -> Faux
# Déplacé : 160_F_CA3.png -> Faux
# Déplacé : 039_F_JC4.jpg -> Faux
# Déplacé : 012_F_IB1.png -> Faux
# Fichier ignoré (classe inconnue) : 104_M.png
# Déplacé : 052_O_JC9.jpg -> Ori
# Déplacé : 154_O_CA3.png -> Ori
# Déplacé : 137_F_JC8.jpg -> Faux
# Déplacé : 068_F_JC4.jpg -> Faux
# Déplacé : 105_O_JC7.jpg -> Ori
# Déplacé : 093_O_JC9.jpg -> Ori
# Déplacé : 127_O_CR1.png -> Ori
# Déplacé : 157_O_JC3.jpg -> Ori
# Déplacé : 191_O_CA3.png -> Ori
# Déplacé : 168_F_CR2.png -> Faux
# Déplacé : 109_F_IB2.png -> Faux
# Déplacé : 124_O_JC8.jpg -> Ori
# Déplacé : 167_F_JC2.jpg -> Faux
# Déplacé : 096_F_JC6.jpg -> Faux
# Déplacé : 091_F_JC3.jpg -> Faux
# Déplacé : 020_F_IB1.png -> Faux
# Déplacé : 072_F_BC1.png -> Faux
# Déplacé : 178_F_JC5.jpg -> Faux
# Déplacé : 056_F_JC2.jpg -> Faux
# Déplacé : 129_F_BC1.png -> Faux
# Déplacé : 098_O_CA1.png -> Ori
# Déplacé : 009_F_JC7.jpg -> Faux
# Déplacé : 060_F_CR2.png -> Faux
# Déplacé : 180_F_BC2.png -> Faux
# Déplacé : 066_F_BC3.png -> Faux
# Déplacé : 096_O_JC1.jpg -> Ori
# Déplacé : 139_O_BC1.png -> Ori
# Déplacé : 023_O_JC3.jpg -> Ori
# Déplacé : 017_O_NA2.png -> Ori
# Déplacé : 099_O_BC2.png -> Ori
# Déplacé : 078_F_CR3.png -> Faux
# Déplacé : 161_F_JC2.jpg -> Faux
# Déplacé : 011_F_JC5.jpg -> Faux
# Déplacé : 183_F.png -> Faux
# Déplacé : 116_O_BC2.png -> Ori
# Déplacé : 106_O_NA2.png -> Ori
# Déplacé : 067_F.png -> Faux
# Déplacé : 157_F_NA3.png -> Faux
# Déplacé : 154_O_BC1.png -> Ori
# Déplacé : 012_F_NA1.png -> Faux
# Déplacé : 093_O_BC2.png -> Ori
# Déplacé : 134_O_IB3.png -> Ori
# Déplacé : 168_F_JC7.jpg -> Faux
# Déplacé : 076_F_IB3.png -> Faux
# Fichier ignoré (classe inconnue) : 169_M.png
# Déplacé : 023_O_BC3.png -> Ori
# Déplacé : 011_O_BC2.png -> Ori
# Déplacé : 145_F_IB2.png -> Faux
# Déplacé : 018_F_CR1.png -> Faux
# Déplacé : 147_F_CA1.png -> Faux
# Déplacé : 071_F_IB3.png -> Faux
# Déplacé : 077_O_JC1.jpg -> Ori
# Déplacé : 098_O_CR2.png -> Ori
# Déplacé : 132_F_JC8.jpg -> Faux
# Déplacé : 100_O_JC3.jpg -> Ori
# Déplacé : 127_F_CR2.png -> Faux
# Déplacé : 007_O_IB2.png -> Ori
# Déplacé : 110_F_CR2.png -> Faux
# Déplacé : 064_F_BC2.png -> Faux
# Déplacé : 110_O_NA2.png -> Ori
# Déplacé : 013_O_IB2.png -> Ori
# Déplacé : 141_F_IB2.png -> Faux
# Déplacé : 170_F_CA3.png -> Faux
# Déplacé : 127_F.png -> Faux
# Déplacé : 029_O_NA3.png -> Ori
# Déplacé : 002_F_IB1.png -> Faux
# Déplacé : 184_O_NA3.png -> Ori
# Déplacé : 147_O_NA3.png -> Ori
# Déplacé : 071_O_CR3.png -> Ori
# Déplacé : 025_O_JC5.jpg -> Ori
# Déplacé : 119_F_CR3.png -> Faux
# Déplacé : 073_O_JC1.jpg -> Ori
# Déplacé : 071_O_JC1.jpg -> Ori
# Déplacé : 068_F_IB3.png -> Faux
# Déplacé : 043_O_CA2.png -> Ori
# Déplacé : 006_O_NA3.png -> Ori
# Déplacé : 087_F_JC6.jpg -> Faux
# Déplacé : 164_O_JC3.jpg -> Ori
# Déplacé : 009_F_BC3.png -> Faux
# Fichier ignoré (classe inconnue) : 159_M.png
# Déplacé : 071_O_JC2.jpg -> Ori
# Déplacé : 022_O_CR3.png -> Ori
# Déplacé : 048_O_BC3.png -> Ori
# Déplacé : 198_O_IB2.png -> Ori
# Déplacé : 036_F_JC4.jpg -> Faux
# Déplacé : 072_F_NA3.png -> Faux
# Déplacé : 162_O_CA3.png -> Ori
# Déplacé : 082_O_IB3.png -> Ori
# Déplacé : 102_F_NA1.png -> Faux
# Fichier ignoré (classe inconnue) : 071_M.png
# Déplacé : 124_F_JC2.jpg -> Faux
# Déplacé : 168_O_NA1.png -> Ori
# Déplacé : 087_O_JC7.jpg -> Ori
# Déplacé : 131_O_CR2.png -> Ori
# Déplacé : 066_O_JC5.jpg -> Ori
# Déplacé : 155_O_BC3.png -> Ori
# Déplacé : 131_O.png -> Ori
# Déplacé : 176_F.png -> Faux
# Déplacé : 109_F_CA2.png -> Faux
# Déplacé : 126_O_CA2.png -> Ori
# Déplacé : 119_F_CA2.png -> Faux
# Déplacé : 102_F_CA3.png -> Faux
# Déplacé : 186_F_CR1.png -> Faux
# Déplacé : 017_O_JC6.jpg -> Ori
# Déplacé : 063_O_CA3.png -> Ori
# Déplacé : 070_F_NA1.png -> Faux
# Déplacé : 021_F_JC5.jpg -> Faux
# Déplacé : 068_O_JC4.jpg -> Ori
# Déplacé : 181_F_CA1.png -> Faux
# Fichier ignoré (classe inconnue) : 195_B.png
# Déplacé : 096_F_JC4.jpg -> Faux
# Déplacé : 099_O_JC8.jpg -> Ori
# Déplacé : 051_O_JC9.jpg -> Ori
# Déplacé : 148_O_NA1.png -> Ori
# Déplacé : 102_F_CA1.png -> Faux
# Déplacé : 088_F_CR1.png -> Faux
# Déplacé : 033_O_NA2.png -> Ori
# Déplacé : 019_F_JC6.jpg -> Faux
# Déplacé : 175_F_JC7.jpg -> Faux
# Déplacé : 099_O_BC3.png -> Ori
# Fichier ignoré (classe inconnue) : 130_B.png
# Déplacé : 188_F_JC6.jpg -> Faux
# Déplacé : 100_O_IB3.png -> Ori
# Déplacé : 155_O_BC2.png -> Ori
# Déplacé : 063_O_JC6.jpg -> Ori
# Déplacé : 130_O.png -> Ori
# Déplacé : 130_F_JC3.jpg -> Faux
# Déplacé : 073_F_JC7.jpg -> Faux
# Déplacé : 010_O_CA2.png -> Ori
# Déplacé : 018_F_JC5.jpg -> Faux
# Déplacé : 051_O_JC2.jpg -> Ori
# Déplacé : 028_F_CR2.png -> Faux
# Déplacé : 057_O_CR3.png -> Ori
# Déplacé : 047_O_JC8.jpg -> Ori
# Déplacé : 009_F_CR3.png -> Faux
# Déplacé : 175_F_JC9.jpg -> Faux
# Déplacé : 137_F_NA3.png -> Faux
# Déplacé : 098_F_JC3.jpg -> Faux
# Déplacé : 037_F_JC6.jpg -> Faux
# Déplacé : 090_F_JC5.jpg -> Faux
# Déplacé : 066_F_NA1.png -> Faux
# Déplacé : 088_F_BC2.png -> Faux
# Déplacé : 050_O.png -> Ori
# Déplacé : 130_O_CA3.png -> Ori
# Déplacé : 168_F_CA2.png -> Faux
# Déplacé : 169_O_CA2.png -> Ori
# Déplacé : 050_O_BC3.png -> Ori
# Déplacé : 081_F_JC4.jpg -> Faux
# Déplacé : 105_O_JC3.jpg -> Ori
# Déplacé : 007_F_JC5.jpg -> Faux
# Déplacé : 040_F_IB1.png -> Faux
# Déplacé : 130_F_JC4.jpg -> Faux
# Déplacé : 189_F_CR1.png -> Faux
# Déplacé : 168_O_BC2.png -> Ori
# Déplacé : 141_F_BC3.png -> Faux
# Déplacé : 163_O_CR1.png -> Ori
# Fichier ignoré (classe inconnue) : 027_B.png
# Déplacé : 080_F.png -> Faux
# Fichier ignoré (classe inconnue) : 171_M.png
# Déplacé : 036_O_JC3.jpg -> Ori
# Déplacé : 143_F_CA3.png -> Faux
# Déplacé : 029_O_CR3.png -> Ori
# Déplacé : 074_O_NA2.png -> Ori
# Déplacé : 050_O_JC1.jpg -> Ori
# Déplacé : 070_O_IB3.png -> Ori
# Déplacé : 037_O.png -> Ori
# Déplacé : 116_F_JC4.jpg -> Faux
# Déplacé : 116_F_CA1.png -> Faux
# Déplacé : 116_F_IB2.png -> Faux
# Déplacé : 122_F_JC1.jpg -> Faux
# Déplacé : 043_O_BC2.png -> Ori
# Déplacé : 109_O_JC9.jpg -> Ori
# Déplacé : 070_F_JC1.jpg -> Faux
# Déplacé : 182_F_CA3.png -> Faux
# Déplacé : 109_O_JC2.jpg -> Ori
# Déplacé : 020_O_IB3.png -> Ori
# Déplacé : 184_F.png -> Faux
# Déplacé : 113_F_JC4.jpg -> Faux
# Déplacé : 061_O_CR2.png -> Ori
# Déplacé : 082_F_JC1.jpg -> Faux
# Déplacé : 149_O_NA1.png -> Ori
# Déplacé : 094_O_JC9.jpg -> Ori
# Déplacé : 060_O_CR3.png -> Ori
# Déplacé : 021_F_NA3.png -> Faux
# Déplacé : 048_O_CR1.png -> Ori
# Déplacé : 078_O_CA3.png -> Ori
# Déplacé : 015_O_BC3.png -> Ori
# Déplacé : 068_O.png -> Ori
# Déplacé : 021_O_JC7.jpg -> Ori
# Déplacé : 023_F_JC1.jpg -> Faux
# Déplacé : 158_O_BC3.png -> Ori
# Déplacé : 179_F_NA1.png -> Faux
# Déplacé : 149_O_CR3.png -> Ori
# Déplacé : 116_O_IB1.png -> Ori
# Déplacé : 106_F_JC2.jpg -> Faux
# Déplacé : 109_O_JC1.jpg -> Ori
# Déplacé : 031_F_JC3.jpg -> Faux
# Déplacé : 179_F_NA3.png -> Faux
# Déplacé : 084_F_JC2.jpg -> Faux
# Déplacé : 106_O_CR1.png -> Ori
# Déplacé : 148_O_NA2.png -> Ori
# Déplacé : 119_F_JC7.jpg -> Faux
# Déplacé : 136_F_JC7.jpg -> Faux
# Déplacé : 061_O_BC2.png -> Ori
# Déplacé : 196_F_JC9.jpg -> Faux
# Déplacé : 182_O_JC6.jpg -> Ori
# Déplacé : 135_O_JC8.jpg -> Ori
# Déplacé : 012_F_JC8.jpg -> Faux
# Déplacé : 070_O_JC4.jpg -> Ori
# Déplacé : 082_O_NA2.png -> Ori
# Déplacé : 089_F_NA3.png -> Faux
# Déplacé : 033_F_JC2.jpg -> Faux
# Déplacé : 148_O_CA2.png -> Ori
# Déplacé : 102_F_JC2.jpg -> Faux
# Déplacé : 142_F_CR2.png -> Faux
# Déplacé : 030_F_IB2.png -> Faux
# Déplacé : 105_F_CA3.png -> Faux
# Déplacé : 183_O_JC2.jpg -> Ori
# Déplacé : 188_O_JC6.jpg -> Ori
# Déplacé : 016_O_JC2.jpg -> Ori
# Déplacé : 197_O_CA3.png -> Ori
# Déplacé : 175_F_CR1.png -> Faux
# Déplacé : 071_F_CR3.png -> Faux
# Déplacé : 162_F_CA3.png -> Faux
# Déplacé : 044_O_JC1.jpg -> Ori
# Déplacé : 137_O_NA2.png -> Ori
# Déplacé : 149_F_JC3.jpg -> Faux
# Déplacé : 145_F_JC4.jpg -> Faux
# Déplacé : 062_F_NA2.png -> Faux
# Déplacé : 028_F_CA3.png -> Faux
# Déplacé : 032_O_JC4.jpg -> Ori
# Déplacé : 111_F_JC7.jpg -> Faux
# Déplacé : 018_O_CR2.png -> Ori
# Déplacé : 023_F_CR2.png -> Faux
# Déplacé : 034_F_CA2.png -> Faux
# Déplacé : 019_F_JC4.jpg -> Faux
# Déplacé : 002_F_JC1.jpg -> Faux
# Déplacé : 088_O_JC4.jpg -> Ori
# Déplacé : 066_O_NA2.png -> Ori
# Déplacé : 088_O_CR1.png -> Ori
# Déplacé : 144_O_BC2.png -> Ori
# Déplacé : 187_O_JC3.jpg -> Ori
# Déplacé : 079_F_IB3.png -> Faux
# Déplacé : 076_F_JC3.jpg -> Faux
# Déplacé : 040_F_CR1.png -> Faux
# Déplacé : 135_O_BC1.png -> Ori
# Déplacé : 045_F.png -> Faux
# Déplacé : 160_F_CR3.png -> Faux
# Déplacé : 096_F_CA2.png -> Faux
# Déplacé : 068_O_IB2.png -> Ori
# Déplacé : 068_F_CA3.png -> Faux
# Déplacé : 069_O_JC5.jpg -> Ori
# Déplacé : 126_F_CR1.png -> Faux
# Déplacé : 035_F_NA1.png -> Faux
# Déplacé : 126_O_BC1.png -> Ori
# Déplacé : 199_F_CA2.png -> Faux
# Déplacé : 151_O_JC5.jpg -> Ori
# Déplacé : 122_F.png -> Faux
# Déplacé : 199_F_BC1.png -> Faux
# Déplacé : 066_F_CA3.png -> Faux
# Déplacé : 098_O_JC9.jpg -> Ori
# Déplacé : 196_O_NA3.png -> Ori
# Déplacé : 099_F_JC2.jpg -> Faux
# Déplacé : 002_F_CR2.png -> Faux
# Déplacé : 110_F_JC1.jpg -> Faux
# Déplacé : 146_F_JC3.jpg -> Faux
# Déplacé : 143_F_JC8.jpg -> Faux
# Déplacé : 034_O_IB2.png -> Ori
# Déplacé : 088_F_JC1.jpg -> Faux
# Déplacé : 156_O_NA2.png -> Ori
# Déplacé : 177_O_NA2.png -> Ori
# Déplacé : 145_F_IB1.png -> Faux
# Déplacé : 188_F_JC2.jpg -> Faux
# Déplacé : 158_F_CA2.png -> Faux
# Déplacé : 125_F_JC8.jpg -> Faux
# Déplacé : 129_F_CR2.png -> Faux
# Déplacé : 004_O_IB3.png -> Ori
# Déplacé : 066_F_CA2.png -> Faux
# Déplacé : 181_O_CR1.png -> Ori
# Déplacé : 143_O_BC1.png -> Ori
# Déplacé : 186_O_JC7.jpg -> Ori
# Déplacé : 069_F_IB3.png -> Faux
# Déplacé : 102_O_JC2.jpg -> Ori
# Déplacé : 118_F_BC3.png -> Faux
# Déplacé : 166_O_BC1.png -> Ori
# Déplacé : 065_F_JC5.jpg -> Faux
# Déplacé : 158_F_IB2.png -> Faux
# Déplacé : 042_F_BC1.png -> Faux
# Déplacé : 138_O.png -> Ori
# Déplacé : 050_F_JC9.jpg -> Faux
# Déplacé : 079_O_IB3.png -> Ori
# Déplacé : 022_F_CR3.png -> Faux
# Déplacé : 170_F_CA1.png -> Faux
# Déplacé : 073_F_CA3.png -> Faux
# Déplacé : 053_O_JC7.jpg -> Ori
# Déplacé : 076_O_NA3.png -> Ori
# Déplacé : 152_O_CA2.png -> Ori
# Déplacé : 102_O_IB1.png -> Ori
# Déplacé : 050_F_CA2.png -> Faux
# Déplacé : 151_O_BC3.png -> Ori
# Déplacé : 115_O_JC2.jpg -> Ori
# Déplacé : 017_F.png -> Faux
# Déplacé : 020_O_CR1.png -> Ori
# Déplacé : 108_O_BC3.png -> Ori
# Déplacé : 070_F_CR1.png -> Faux
# Déplacé : 183_F_JC5.jpg -> Faux
# Déplacé : 023_F_IB3.png -> Faux
# Déplacé : 156_O_JC6.jpg -> Ori
# Déplacé : 161_O_JC8.jpg -> Ori
# Fichier ignoré (classe inconnue) : 106_B.png
# Déplacé : 056_O_JC4.jpg -> Ori
# Déplacé : 196_O_JC2.jpg -> Ori
# Déplacé : 196_F_NA3.png -> Faux
# Déplacé : 129_F_JC5.jpg -> Faux
# Déplacé : 021_F_IB3.png -> Faux
# Déplacé : 042_O_NA1.png -> Ori
# Déplacé : 068_F_JC9.jpg -> Faux
# Déplacé : 180_F_CR3.png -> Faux
# Déplacé : 184_O_JC9.jpg -> Ori
# Déplacé : 114_F_JC9.jpg -> Faux
# Déplacé : 012_O_IB2.png -> Ori
# Déplacé : 192_F_CR3.png -> Faux
# Déplacé : 160_F_JC2.jpg -> Faux
# Déplacé : 094_F_BC2.png -> Faux
# Déplacé : 029_F.png -> Faux
# Déplacé : 078_F_CR1.png -> Faux
# Déplacé : 145_F_BC1.png -> Faux
# Déplacé : 065_F_JC7.jpg -> Faux
# Déplacé : 052_O_JC8.jpg -> Ori
# Déplacé : 090_F_JC7.jpg -> Faux
# Fichier ignoré (classe inconnue) : 036_M.png
# Déplacé : 044_O_JC2.jpg -> Ori
# Déplacé : 192_O_CR3.png -> Ori
# Déplacé : 046_F_JC1.jpg -> Faux
# Déplacé : 174_O_JC2.jpg -> Ori
# Déplacé : 135_F_JC8.jpg -> Faux
# Fichier ignoré (classe inconnue) : 034_M.png
# Déplacé : 060_F_JC3.jpg -> Faux
# Déplacé : 047_F_NA3.png -> Faux
# Déplacé : 007_F_CA2.png -> Faux
# Déplacé : 053_O_CR1.png -> Ori
# Déplacé : 048_F_IB3.png -> Faux
# Déplacé : 152_F_CR1.png -> Faux
# Déplacé : 043_F_JC2.jpg -> Faux
# Déplacé : 116_O_JC4.jpg -> Ori
# Déplacé : 198_F_IB1.png -> Faux
# Déplacé : 063_O_CA1.png -> Ori
# Déplacé : 117_F_NA1.png -> Faux
# Déplacé : 116_O_BC1.png -> Ori
# Déplacé : 040_O_JC1.jpg -> Ori
# Déplacé : 062_O_JC1.jpg -> Ori
# Déplacé : 159_O_CA1.png -> Ori
# Déplacé : 025_F_CR3.png -> Faux
# Déplacé : 183_O_JC4.jpg -> Ori
# Déplacé : 088_O_JC8.jpg -> Ori
# Déplacé : 090_O_NA1.png -> Ori
# Déplacé : 191_F_IB1.png -> Faux
# Déplacé : 067_F_IB2.png -> Faux
# Déplacé : 016_F.png -> Faux
# Déplacé : 076_O_JC5.jpg -> Ori
# Déplacé : 185_F_CR1.png -> Faux
# Déplacé : 006_O_NA1.png -> Ori
# Déplacé : 120_F_NA1.png -> Faux
# Déplacé : 012_F_NA3.png -> Faux
# Déplacé : 160_F_JC7.jpg -> Faux
# Déplacé : 072_F_NA2.png -> Faux
# Déplacé : 179_F.png -> Faux
# Déplacé : 072_O_NA3.png -> Ori
# Déplacé : 030_F_JC8.jpg -> Faux
# Déplacé : 096_O_CA3.png -> Ori
# Déplacé : 199_O_NA2.png -> Ori
# Déplacé : 123_O_CR1.png -> Ori
# Déplacé : 016_O_CR2.png -> Ori
# Déplacé : 138_F_JC3.jpg -> Faux
# Déplacé : 100_F_CR3.png -> Faux
# Déplacé : 162_F_CA1.png -> Faux
# Fichier ignoré (classe inconnue) : 091_M.png
# Déplacé : 189_F_JC5.jpg -> Faux
# Déplacé : 176_F_JC4.jpg -> Faux
# Déplacé : 117_O_NA2.png -> Ori
# Déplacé : 080_F_IB3.png -> Faux
# Déplacé : 145_O_IB2.png -> Ori
# Fichier ignoré (classe inconnue) : 121_B.png
# Déplacé : 146_O_CA3.png -> Ori
# Déplacé : 040_F_NA1.png -> Faux
# Déplacé : 178_F_NA3.png -> Faux
# Déplacé : 044_F_BC2.png -> Faux
# Déplacé : 095_O_IB1.png -> Ori
# Déplacé : 182_F_JC3.jpg -> Faux
# Déplacé : 139_O_CR2.png -> Ori
# Déplacé : 121_O_JC8.jpg -> Ori
# Déplacé : 031_F_BC1.png -> Faux
# Déplacé : 055_O_BC3.png -> Ori
# Déplacé : 187_F_NA3.png -> Faux
# Déplacé : 076_F_JC7.jpg -> Faux
# Déplacé : 050_F_IB1.png -> Faux
# Fichier ignoré (classe inconnue) : 145_M.png
# Déplacé : 019_F_JC2.jpg -> Faux
# Déplacé : 103_O_CR3.png -> Ori
# Déplacé : 159_O_CR3.png -> Ori
# Déplacé : 127_F_IB2.png -> Faux
# Déplacé : 066_F_JC7.jpg -> Faux
# Déplacé : 151_F_JC9.jpg -> Faux
# Déplacé : 125_F_CA2.png -> Faux
# Déplacé : 191_O_CR3.png -> Ori
# Déplacé : 134_F_JC3.jpg -> Faux
# Déplacé : 141_F_JC1.jpg -> Faux
# Déplacé : 014_F_NA3.png -> Faux
# Déplacé : 102_F.png -> Faux
# Fichier ignoré (classe inconnue) : 149_M.png
# Déplacé : 023_O_NA3.png -> Ori
# Fichier ignoré (classe inconnue) : 148_B.png
# Déplacé : 165_O_JC3.jpg -> Ori
# Déplacé : 177_F_CA3.png -> Faux
# Déplacé : 111_O_BC3.png -> Ori
# Déplacé : 174_F_JC6.jpg -> Faux
# Déplacé : 180_F_JC8.jpg -> Faux
# Déplacé : 114_O_JC1.jpg -> Ori
# Déplacé : 116_F_IB1.png -> Faux
# Déplacé : 183_F_BC1.png -> Faux
# Déplacé : 061_O_CA2.png -> Ori
# Fichier ignoré (classe inconnue) : 070_M.png
# Déplacé : 122_F_CR2.png -> Faux
# Fichier ignoré (classe inconnue) : 136_B.png
# Déplacé : 162_O_JC7.jpg -> Ori
# Déplacé : 028_O_JC4.jpg -> Ori
# Déplacé : 032_F_BC2.png -> Faux
# Déplacé : 145_F_BC3.png -> Faux
# Déplacé : 169_F_JC2.jpg -> Faux
# Déplacé : 089_F_BC1.png -> Faux
# Déplacé : 172_O_JC7.jpg -> Ori
# Déplacé : 177_F_JC9.jpg -> Faux
# Déplacé : 109_O_IB2.png -> Ori
# Déplacé : 164_O_IB1.png -> Ori
# Déplacé : 157_O_CA3.png -> Ori
# Déplacé : 114_O_BC1.png -> Ori
# Déplacé : 088_F_JC8.jpg -> Faux
# Déplacé : 021_O_CR1.png -> Ori
# Déplacé : 153_F_JC1.jpg -> Faux
# Déplacé : 076_O_CA1.png -> Ori
# Déplacé : 189_F_JC3.jpg -> Faux
# Déplacé : 158_O_JC3.jpg -> Ori
# Déplacé : 105_O_JC1.jpg -> Ori
# Déplacé : 097_F_CR1.png -> Faux
# Déplacé : 099_F_CR2.png -> Faux
# Déplacé : 138_O_IB1.png -> Ori
# Déplacé : 094_F_BC1.png -> Faux
# Déplacé : 111_O_CR2.png -> Ori
# Déplacé : 034_O_CR3.png -> Ori
# Déplacé : 152_F_NA3.png -> Faux
# Déplacé : 003_F_JC9.jpg -> Faux
# Déplacé : 144_F_CA1.png -> Faux
# Déplacé : 041_O_BC1.png -> Ori
# Déplacé : 199_O_JC8.jpg -> Ori
# Déplacé : 089_O_CR2.png -> Ori
# Déplacé : 149_F_CR3.png -> Faux
# Déplacé : 034_O_JC7.jpg -> Ori
# Déplacé : 169_F.png -> Faux
# Déplacé : 200_O_JC3.jpg -> Ori
# Déplacé : 146_F_CR1.png -> Faux
# Déplacé : 182_O.png -> Ori
# Déplacé : 080_F_JC8.jpg -> Faux
# Déplacé : 028_O_BC3.png -> Ori
# Déplacé : 134_F_JC2.jpg -> Faux
# Déplacé : 029_F_JC3.jpg -> Faux
# Déplacé : 035_F_JC1.jpg -> Faux
# Déplacé : 077_O_CA3.png -> Ori
# Déplacé : 170_O_IB3.png -> Ori
# Déplacé : 155_O_NA1.png -> Ori
# Déplacé : 096_O_CA2.png -> Ori
# Déplacé : 199_O_IB2.png -> Ori
# Déplacé : 046_F_JC8.jpg -> Faux
# Déplacé : 131_F_JC6.jpg -> Faux
# Déplacé : 100_F_JC1.jpg -> Faux
# Déplacé : 114_O_CA3.png -> Ori
# Déplacé : 078_F_JC7.jpg -> Faux
# Déplacé : 095_F_BC3.png -> Faux
# Déplacé : 094_O_BC3.png -> Ori
# Déplacé : 105_O_IB1.png -> Ori
# Déplacé : 001_O_JC1.jpg -> Ori
# Déplacé : 184_O_IB3.png -> Ori
# Déplacé : 159_O_CA3.png -> Ori
# Déplacé : 200_F_JC3.jpg -> Faux
# Déplacé : 008_O_CR3.png -> Ori
# Déplacé : 113_F_IB2.png -> Faux
# Déplacé : 179_O_JC3.jpg -> Ori
# Déplacé : 186_O_NA3.png -> Ori
# Déplacé : 175_O_IB1.png -> Ori
# Déplacé : 193_F_CR2.png -> Faux
# Déplacé : 030_F_JC2.jpg -> Faux
# Déplacé : 015_F_BC3.png -> Faux
# Déplacé : 002_O_CA3.png -> Ori
# Déplacé : 048_F_BC3.png -> Faux
# Déplacé : 183_O_NA3.png -> Ori
# Déplacé : 170_F_JC3.jpg -> Faux
# Déplacé : 162_F_BC3.png -> Faux
# Déplacé : 090_O_BC2.png -> Ori
# Déplacé : 141_F_IB3.png -> Faux
# Déplacé : 011_F_JC8.jpg -> Faux
# Déplacé : 199_O_JC4.jpg -> Ori
# Déplacé : 162_O_IB2.png -> Ori
# Déplacé : 075_F_JC3.jpg -> Faux
# Déplacé : 061_F_CA2.png -> Faux
# Déplacé : 006_F_CA1.png -> Faux
# Déplacé : 128_O_NA2.png -> Ori
# Déplacé : 112_F_JC1.jpg -> Faux
# Déplacé : 118_F_JC3.jpg -> Faux
# Déplacé : 153_F_NA2.png -> Faux
# Déplacé : 181_O_BC3.png -> Ori
# Déplacé : 028_F_JC8.jpg -> Faux
# Déplacé : 100_O_NA2.png -> Ori
# Déplacé : 157_O_CR2.png -> Ori
# Déplacé : 010_F_BC1.png -> Faux
# Fichier ignoré (classe inconnue) : 105_M.png
# Fichier ignoré (classe inconnue) : 074_M.png
# Déplacé : 106_F_IB1.png -> Faux
# Déplacé : 189_F_JC6.jpg -> Faux
# Déplacé : 112_F_JC7.jpg -> Faux
# Déplacé : 200_F_BC2.png -> Faux
# Déplacé : 197_O_JC2.jpg -> Ori
# Déplacé : 029_O_CA3.png -> Ori
# Déplacé : 047_O_JC4.jpg -> Ori
# Déplacé : 126_O_NA2.png -> Ori
# Déplacé : 012_F_IB2.png -> Faux
# Déplacé : 131_F_CA3.png -> Faux
# Déplacé : 186_O_BC3.png -> Ori
# Déplacé : 031_F_CA2.png -> Faux
# Déplacé : 141_F_IB1.png -> Faux
# Déplacé : 126_F_BC1.png -> Faux
# Fichier ignoré (classe inconnue) : 118_B.png
# Déplacé : 060_F_CA1.png -> Faux
# Déplacé : 150_F_JC5.jpg -> Faux
# Déplacé : 095_F_IB3.png -> Faux
# Déplacé : 029_O_JC8.jpg -> Ori
# Déplacé : 102_O_BC3.png -> Ori
# Déplacé : 006_O_CR1.png -> Ori
# Déplacé : 093_O_JC2.jpg -> Ori
# Déplacé : 135_O_JC3.jpg -> Ori
# Déplacé : 052_O_JC2.jpg -> Ori
# Déplacé : 113_O_JC7.jpg -> Ori
# Déplacé : 029_F_IB3.png -> Faux
# Déplacé : 047_O_CR1.png -> Ori
# Déplacé : 121_F_JC7.jpg -> Faux
# Déplacé : 055_O_CA2.png -> Ori
# Déplacé : 194_F_CA1.png -> Faux
# Déplacé : 195_O_JC5.jpg -> Ori
# Déplacé : 115_O_JC8.jpg -> Ori
# Déplacé : 090_F_JC4.jpg -> Faux
# Déplacé : 045_F_CR3.png -> Faux
# Déplacé : 165_O_BC3.png -> Ori
# Déplacé : 022_O_JC2.jpg -> Ori
# Déplacé : 049_O_BC2.png -> Ori
# Déplacé : 056_O_JC8.jpg -> Ori
# Déplacé : 033_F_BC3.png -> Faux
# Déplacé : 183_F_JC1.jpg -> Faux
# Déplacé : 124_F_BC3.png -> Faux
# Déplacé : 092_O_JC1.jpg -> Ori
# Déplacé : 031_F_JC5.jpg -> Faux
# Déplacé : 069_F_JC6.jpg -> Faux
# Déplacé : 197_F_JC7.jpg -> Faux
# Déplacé : 024_O_CA1.png -> Ori
# Déplacé : 058_O_BC3.png -> Ori
# Déplacé : 129_F_JC7.jpg -> Faux
# Déplacé : 136_O_NA1.png -> Ori
# Déplacé : 096_F_JC3.jpg -> Faux
# Déplacé : 014_F.png -> Faux
# Déplacé : 156_O_NA3.png -> Ori
# Déplacé : 144_O_JC5.jpg -> Ori
# Déplacé : 110_F_JC3.jpg -> Faux
# Déplacé : 009_O_IB2.png -> Ori
# Déplacé : 031_F_JC1.jpg -> Faux
# Déplacé : 079_F_JC6.jpg -> Faux
# Déplacé : 048_O_IB3.png -> Ori
# Déplacé : 016_O_JC6.jpg -> Ori
# Déplacé : 083_O.png -> Ori
# Déplacé : 068_F_JC1.jpg -> Faux
# Déplacé : 130_O_BC1.png -> Ori
# Fichier ignoré (classe inconnue) : 179_B.png
# Déplacé : 104_F.png -> Faux
# Déplacé : 189_O_JC7.jpg -> Ori
# Déplacé : 052_O_IB3.png -> Ori
# Déplacé : 023_O_CR1.png -> Ori
# Déplacé : 100_F.png -> Faux
# Déplacé : 081_F_JC1.jpg -> Faux
# Déplacé : 129_F_JC2.jpg -> Faux
# Déplacé : 147_F_CA2.png -> Faux
# Déplacé : 012_F_CA2.png -> Faux
# Déplacé : 013_O_JC1.jpg -> Ori
# Déplacé : 025_O_JC7.jpg -> Ori
# Déplacé : 142_O_JC4.jpg -> Ori
# Déplacé : 055_F_BC2.png -> Faux
# Déplacé : 120_F_JC3.jpg -> Faux
# Déplacé : 083_O_NA3.png -> Ori
# Déplacé : 034_F_JC6.jpg -> Faux
# Déplacé : 136_F_JC3.jpg -> Faux
# Déplacé : 029_F_JC9.jpg -> Faux
# Déplacé : 067_O_CA3.png -> Ori
# Déplacé : 019_F.png -> Faux
# Déplacé : 042_O_CA3.png -> Ori
# Déplacé : 018_O_JC9.jpg -> Ori
# Fichier ignoré (classe inconnue) : 072_M.png
# Déplacé : 008_O_IB1.png -> Ori
# Déplacé : 159_O_JC8.jpg -> Ori
# Déplacé : 081_F_CA1.png -> Faux
# Déplacé : 089_F_JC7.jpg -> Faux
# Déplacé : 187_O_JC2.jpg -> Ori
# Déplacé : 200_O_CR2.png -> Ori
# Déplacé : 125_F_NA2.png -> Faux
# Déplacé : 049_O_BC3.png -> Ori
# Déplacé : 014_F_IB3.png -> Faux
# Déplacé : 163_O_BC1.png -> Ori
# Déplacé : 186_O_BC2.png -> Ori
# Déplacé : 139_O_CA2.png -> Ori
# Déplacé : 130_F_JC9.jpg -> Faux
# Déplacé : 200_O_IB3.png -> Ori
# Déplacé : 012_F_JC7.jpg -> Faux
# Déplacé : 160_F_NA3.png -> Faux
# Déplacé : 003_F_JC8.jpg -> Faux
# Déplacé : 094_F_CR1.png -> Faux
# Déplacé : 150_O_JC8.jpg -> Ori
# Déplacé : 141_O_BC2.png -> Ori
# Déplacé : 167_F_CR2.png -> Faux
# Fichier ignoré (classe inconnue) : 147_B.png
# Déplacé : 015_F_CA3.png -> Faux
# Déplacé : 067_F_NA3.png -> Faux
# Déplacé : 173_F_BC2.png -> Faux
# Déplacé : 014_O_JC5.jpg -> Ori
# Déplacé : 117_O_BC2.png -> Ori
# Déplacé : 109_F_CR3.png -> Faux
# Déplacé : 130_O_NA3.png -> Ori
# Déplacé : 197_O_JC3.jpg -> Ori
# Déplacé : 044_O_CA1.png -> Ori
# Déplacé : 150_F_JC7.jpg -> Faux
# Déplacé : 038_O_JC3.jpg -> Ori
# Déplacé : 091_O_JC1.jpg -> Ori
# Déplacé : 106_O_JC8.jpg -> Ori
# Déplacé : 021_O_JC9.jpg -> Ori
# Déplacé : 074_F_BC1.png -> Faux
# Déplacé : 102_F_NA3.png -> Faux
# Déplacé : 122_F_CA3.png -> Faux
# Déplacé : 148_F_CR1.png -> Faux
# Déplacé : 059_F_JC9.jpg -> Faux
# Fichier ignoré (classe inconnue) : 111_B.png
# Déplacé : 061_F_CR1.png -> Faux
# Déplacé : 063_F_CR2.png -> Faux
# Déplacé : 023_F_JC4.jpg -> Faux
# Déplacé : 153_F_JC3.jpg -> Faux
# Déplacé : 001_O_JC5.jpg -> Ori
# Déplacé : 162_F_IB2.png -> Faux
# Déplacé : 088_F_BC1.png -> Faux
# Déplacé : 057_F_CR2.png -> Faux
# Déplacé : 149_O_CA1.png -> Ori
# Déplacé : 104_O_BC2.png -> Ori
# Déplacé : 113_F_JC5.jpg -> Faux
# Déplacé : 193_F_BC2.png -> Faux
# Déplacé : 163_O_JC6.jpg -> Ori
# Déplacé : 070_F_JC4.jpg -> Faux
# Déplacé : 030_O_BC2.png -> Ori
# Déplacé : 088_F_CA2.png -> Faux
# Déplacé : 118_F_CA2.png -> Faux
# Déplacé : 115_F_JC6.jpg -> Faux
# Déplacé : 154_F_NA1.png -> Faux
# Déplacé : 023_O_CR3.png -> Ori
# Déplacé : 184_F_BC1.png -> Faux
# Déplacé : 097_F_JC5.jpg -> Faux
# Déplacé : 184_F_JC9.jpg -> Faux
# Déplacé : 047_F_NA1.png -> Faux
# Déplacé : 023_F_CR1.png -> Faux
# Déplacé : 031_O_JC4.jpg -> Ori
# Déplacé : 142_O_NA1.png -> Ori
# Déplacé : 121_F_JC6.jpg -> Faux
# Déplacé : 130_O_BC2.png -> Ori
# Déplacé : 127_O_IB2.png -> Ori
# Déplacé : 041_O_JC2.jpg -> Ori
# Déplacé : 062_F.png -> Faux
# Déplacé : 017_O_JC9.jpg -> Ori
# Déplacé : 026_O_CA1.png -> Ori
# Déplacé : 030_O_JC2.jpg -> Ori
# Déplacé : 064_O_CR1.png -> Ori
# Déplacé : 087_F_IB1.png -> Faux
# Déplacé : 100_O_NA3.png -> Ori
# Déplacé : 167_O_JC6.jpg -> Ori
# Déplacé : 158_F.png -> Faux
# Déplacé : 115_O_JC3.jpg -> Ori
# Déplacé : 187_F_IB3.png -> Faux
# Fichier ignoré (classe inconnue) : 045_M.png
# Déplacé : 197_F.png -> Faux
# Déplacé : 193_F_IB1.png -> Faux
# Déplacé : 097_O_NA2.png -> Ori
# Déplacé : 044_F_IB3.png -> Faux
# Déplacé : 195_O_IB2.png -> Ori
# Déplacé : 174_F_CA2.png -> Faux
# Déplacé : 044_F_CR1.png -> Faux
# Déplacé : 076_F_NA2.png -> Faux
# Déplacé : 081_F_BC2.png -> Faux
# Déplacé : 160_F_JC4.jpg -> Faux
# Déplacé : 169_F_CA1.png -> Faux
# Déplacé : 094_O_CR3.png -> Ori
# Déplacé : 053_O_NA1.png -> Ori
# Déplacé : 043_O_NA3.png -> Ori
# Déplacé : 193_O_BC1.png -> Ori
# Déplacé : 179_O_CA1.png -> Ori
# Déplacé : 060_O_BC3.png -> Ori
# Déplacé : 195_O_BC2.png -> Ori
# Déplacé : 147_O_CA1.png -> Ori
# Déplacé : 005_F_JC1.jpg -> Faux
# Déplacé : 053_F_JC5.jpg -> Faux
# Déplacé : 009_F_IB1.png -> Faux
# Déplacé : 197_F_JC4.jpg -> Faux
# Déplacé : 055_O_JC6.jpg -> Ori
# Déplacé : 080_F_JC5.jpg -> Faux
# Déplacé : 016_F_CA3.png -> Faux
# Déplacé : 169_O_JC4.jpg -> Ori
# Déplacé : 076_F_JC9.jpg -> Faux
# Déplacé : 107_O_JC4.jpg -> Ori
# Déplacé : 031_O_CA1.png -> Ori
# Déplacé : 127_F_NA3.png -> Faux
# Déplacé : 146_F_CA1.png -> Faux
# Déplacé : 032_O_CA2.png -> Ori
# Déplacé : 011_O_NA1.png -> Ori
# Déplacé : 005_O_JC6.jpg -> Ori
# Déplacé : 081_F_BC1.png -> Faux
# Déplacé : 045_O_NA1.png -> Ori
# Déplacé : 070_F_NA2.png -> Faux
# Déplacé : 051_F_JC4.jpg -> Faux
# Fichier ignoré (classe inconnue) : 098_M.png
# Déplacé : 036_F_CR3.png -> Faux
# Déplacé : 048_F_CA1.png -> Faux
# Déplacé : 107_F_NA2.png -> Faux
# Déplacé : 064_O_CA1.png -> Ori
# Déplacé : 147_O_IB2.png -> Ori
# Déplacé : 109_F_JC7.jpg -> Faux
# Déplacé : 115_O_CA3.png -> Ori
# Déplacé : 162_O_CR1.png -> Ori
# Déplacé : 156_F_NA2.png -> Faux
# Déplacé : 137_O_JC7.jpg -> Ori
# Déplacé : 064_F_JC1.jpg -> Faux
# Fichier ignoré (classe inconnue) : 156_M.png
# Déplacé : 174_O_BC2.png -> Ori
# Déplacé : 149_O_CR1.png -> Ori
# Déplacé : 154_O_BC2.png -> Ori
# Déplacé : 196_F_CR3.png -> Faux
# Déplacé : 066_O_CA2.png -> Ori
# Déplacé : 040_F.png -> Faux
# Déplacé : 089_O_JC1.jpg -> Ori
# Déplacé : 170_F_NA3.png -> Faux
# Déplacé : 036_F.png -> Faux
# Déplacé : 031_F_IB1.png -> Faux
# Fichier ignoré (classe inconnue) : 096_M.png
# Déplacé : 177_O_BC2.png -> Ori
# Déplacé : 061_F_NA3.png -> Faux
# Déplacé : 099_O_CR3.png -> Ori
# Déplacé : 002_F_IB3.png -> Faux
# Déplacé : 077_F_IB3.png -> Faux
# Fichier ignoré (classe inconnue) : 151_M.png
# Déplacé : 119_F_JC1.jpg -> Faux
# Déplacé : 073_O_JC9.jpg -> Ori
# Déplacé : 105_F_JC2.jpg -> Faux
# Déplacé : 178_O_IB3.png -> Ori
# Déplacé : 138_O_JC4.jpg -> Ori
# Déplacé : 028_O_JC7.jpg -> Ori
# Déplacé : 076_F_JC6.jpg -> Faux
# Déplacé : 165_F_NA1.png -> Faux
# Déplacé : 004_F_BC2.png -> Faux
# Déplacé : 149_O_NA3.png -> Ori
# Déplacé : 121_F_BC2.png -> Faux
# Déplacé : 146_O.png -> Ori
# Déplacé : 025_O_JC1.jpg -> Ori
# Déplacé : 139_O_NA2.png -> Ori
# Déplacé : 078_F_JC2.jpg -> Faux
# Déplacé : 114_O.png -> Ori
# Déplacé : 064_F_JC2.jpg -> Faux
# Déplacé : 057_O_CA3.png -> Ori
# Déplacé : 071_O_IB1.png -> Ori
# Déplacé : 125_O_JC6.jpg -> Ori
# Déplacé : 168_O_JC2.jpg -> Ori
# Déplacé : 178_F_BC3.png -> Faux
# Déplacé : 090_F_JC8.jpg -> Faux
# Déplacé : 181_O_NA1.png -> Ori
# Fichier ignoré (classe inconnue) : 059_B.png
# Déplacé : 087_O_IB1.png -> Ori
# Déplacé : 013_O_BC1.png -> Ori
# Déplacé : 103_F_JC1.jpg -> Faux
# Déplacé : 097_F_NA1.png -> Faux
# Déplacé : 116_F_JC9.jpg -> Faux
# Déplacé : 018_F_JC8.jpg -> Faux
# Déplacé : 104_F_IB2.png -> Faux
# Déplacé : 144_O_NA3.png -> Ori
# Déplacé : 078_O.png -> Ori
# Déplacé : 014_F_IB1.png -> Faux
# Fichier ignoré (classe inconnue) : 067_M.png
# Déplacé : 133_O_CA3.png -> Ori
# Déplacé : 170_F_NA2.png -> Faux
# Déplacé : 004_F_JC1.jpg -> Faux
# Déplacé : 181_F_JC1.jpg -> Faux
# Déplacé : 015_F_BC1.png -> Faux
# Déplacé : 088_O_JC6.jpg -> Ori
# Déplacé : 181_F_NA2.png -> Faux
# Déplacé : 080_O_NA2.png -> Ori
# Déplacé : 154_O_JC1.jpg -> Ori
# Déplacé : 103_O_CR2.png -> Ori
# Déplacé : 155_O_JC7.jpg -> Ori
# Déplacé : 151_O_CR1.png -> Ori
# Déplacé : 128_O_JC9.jpg -> Ori
# Déplacé : 052_F_CR2.png -> Faux
# Déplacé : 177_O_CA3.png -> Ori
# Déplacé : 043_F_BC1.png -> Faux
# Déplacé : 015_O_JC7.jpg -> Ori
# Déplacé : 024_F_JC8.jpg -> Faux
# Déplacé : 189_F_CR3.png -> Faux
# Déplacé : 196_O_NA1.png -> Ori
# Déplacé : 134_O_JC2.jpg -> Ori
# Déplacé : 085_F_JC3.jpg -> Faux
# Déplacé : 133_O.png -> Ori
# Déplacé : 008_O_IB3.png -> Ori
# Déplacé : 128_F_BC2.png -> Faux
# Déplacé : 196_F_JC6.jpg -> Faux
# Déplacé : 197_F_JC9.jpg -> Faux
# Déplacé : 002_O_CA1.png -> Ori
# Déplacé : 010_O_CA3.png -> Ori
# Déplacé : 071_F_IB2.png -> Faux
# Déplacé : 112_O_NA3.png -> Ori
# Déplacé : 107_O_CR3.png -> Ori
# Déplacé : 049_O_CR1.png -> Ori
# Déplacé : 027_F_NA3.png -> Faux
# Déplacé : 086_O_JC8.jpg -> Ori
# Déplacé : 079_O_CR2.png -> Ori
# Déplacé : 199_F.png -> Faux
# Déplacé : 013_F_JC5.jpg -> Faux
# Déplacé : 190_O_NA2.png -> Ori
# Déplacé : 107_F_JC9.jpg -> Faux
# Déplacé : 117_F_JC3.jpg -> Faux
# Déplacé : 125_F_IB1.png -> Faux
# Déplacé : 007_F_CA3.png -> Faux
# Déplacé : 155_F_NA3.png -> Faux
# Déplacé : 189_O.png -> Ori
# Déplacé : 033_O_JC4.jpg -> Ori
# Fichier ignoré (classe inconnue) : 059_M.png
# Déplacé : 196_O_JC1.jpg -> Ori
# Déplacé : 194_O_JC9.jpg -> Ori
# Déplacé : 180_O_CA2.png -> Ori
# Déplacé : 031_F_JC6.jpg -> Faux
# Déplacé : 004_O_CR2.png -> Ori
# Déplacé : 052_O_CA1.png -> Ori
# Déplacé : 003_O_JC5.jpg -> Ori
# Déplacé : 058_F.png -> Faux
# Déplacé : 081_F_CR1.png -> Faux
# Déplacé : 013_O_CA2.png -> Ori
# Déplacé : 160_O_JC5.jpg -> Ori
# Déplacé : 054_F_JC5.jpg -> Faux
# Déplacé : 150_F_CA2.png -> Faux
# Déplacé : 005_F_CR1.png -> Faux
# Déplacé : 112_F_CA2.png -> Faux
# Déplacé : 018_F_CA3.png -> Faux
# Déplacé : 049_F_CR1.png -> Faux
# Déplacé : 146_O_IB3.png -> Ori
# Déplacé : 125_O_BC1.png -> Ori
# Déplacé : 179_F_IB3.png -> Faux
# Déplacé : 163_O.png -> Ori
# Déplacé : 179_F_NA2.png -> Faux
# Déplacé : 181_F_CR1.png -> Faux
# Déplacé : 040_F_BC1.png -> Faux
# Déplacé : 179_O_IB3.png -> Ori
# Déplacé : 182_F_JC5.jpg -> Faux
# Déplacé : 183_F_BC3.png -> Faux
# Déplacé : 153_O_JC9.jpg -> Ori
# Déplacé : 033_F_JC6.jpg -> Faux
# Déplacé : 057_F_CR3.png -> Faux
# Déplacé : 122_O_JC3.jpg -> Ori
# Déplacé : 155_F_JC7.jpg -> Faux
# Déplacé : 136_F_CR1.png -> Faux
# Déplacé : 120_O_JC3.jpg -> Ori
# Déplacé : 119_F_IB1.png -> Faux
# Déplacé : 018_F_IB2.png -> Faux
# Déplacé : 163_F_JC5.jpg -> Faux
# Déplacé : 134_F_CA2.png -> Faux
# Déplacé : 064_F_JC6.jpg -> Faux
# Déplacé : 090_O_IB2.png -> Ori
# Déplacé : 118_F_JC1.jpg -> Faux
# Déplacé : 163_O_IB1.png -> Ori
# Déplacé : 173_O_IB3.png -> Ori
# Déplacé : 045_O_JC4.jpg -> Ori
# Déplacé : 187_O_NA3.png -> Ori
# Déplacé : 027_O_IB3.png -> Ori
# Déplacé : 099_O_JC5.jpg -> Ori
# Déplacé : 130_O_JC9.jpg -> Ori
# Déplacé : 171_O.png -> Ori
# Déplacé : 034_O_JC9.jpg -> Ori
# Déplacé : 168_O_CR1.png -> Ori
# Déplacé : 107_O_BC2.png -> Ori
# Déplacé : 148_F_NA3.png -> Faux
# Déplacé : 195_F_JC3.jpg -> Faux
# Déplacé : 067_F_CR1.png -> Faux
# Déplacé : 158_O_CR2.png -> Ori
# Déplacé : 101_F_BC2.png -> Faux
# Déplacé : 112_F_CR3.png -> Faux
# Déplacé : 197_O_IB3.png -> Ori
# Déplacé : 084_F_JC8.jpg -> Faux
# Déplacé : 023_F_JC7.jpg -> Faux
# Déplacé : 010_F_BC3.png -> Faux
# Déplacé : 188_F_BC3.png -> Faux
# Déplacé : 027_F_IB2.png -> Faux
# Déplacé : 139_O_JC3.jpg -> Ori
# Déplacé : 005_O_BC2.png -> Ori
# Déplacé : 059_O_IB2.png -> Ori
# Déplacé : 036_O_JC8.jpg -> Ori
# Déplacé : 096_O_IB1.png -> Ori
# Déplacé : 165_O_IB2.png -> Ori
# Déplacé : 141_F_JC8.jpg -> Faux
# Déplacé : 103_O_IB3.png -> Ori
# Déplacé : 056_F_CA2.png -> Faux
# Déplacé : 058_F_NA1.png -> Faux
# Déplacé : 066_O_JC6.jpg -> Ori
# Déplacé : 013_F_CA1.png -> Faux
# Déplacé : 119_O_NA1.png -> Ori
# Déplacé : 063_O_NA1.png -> Ori
# Déplacé : 007_O_JC6.jpg -> Ori
# Déplacé : 156_F_JC6.jpg -> Faux
# Déplacé : 032_F_JC1.jpg -> Faux
# Déplacé : 102_F_JC8.jpg -> Faux
# Déplacé : 187_O_CR1.png -> Ori
# Déplacé : 159_O_CA2.png -> Ori
# Déplacé : 030_F_CA3.png -> Faux
# Déplacé : 086_F_JC2.jpg -> Faux
# Déplacé : 188_F_IB2.png -> Faux
# Déplacé : 167_O_CR2.png -> Ori
# Déplacé : 132_F_CA3.png -> Faux
# Fichier ignoré (classe inconnue) : 068_B.png
# Déplacé : 152_F_BC1.png -> Faux
# Déplacé : 118_F_CA1.png -> Faux
# Déplacé : 101_F_JC7.jpg -> Faux
# Déplacé : 173_F_IB3.png -> Faux
# Déplacé : 003_O_BC3.png -> Ori
# Déplacé : 123_O_JC7.jpg -> Ori
# Déplacé : 070_O_NA2.png -> Ori
# Déplacé : 113_F_CA2.png -> Faux
# Déplacé : 060_O_JC4.jpg -> Ori
# Déplacé : 064_F_BC3.png -> Faux
# Déplacé : 038_F_JC8.jpg -> Faux
# Déplacé : 016_F_IB2.png -> Faux
# Déplacé : 132_F_NA2.png -> Faux
# Déplacé : 114_O_CA2.png -> Ori
# Déplacé : 045_O_BC3.png -> Ori
# Déplacé : 053_F_CR1.png -> Faux
# Déplacé : 054_O_JC9.jpg -> Ori
# Déplacé : 083_O_CR1.png -> Ori
# Déplacé : 163_F_CR3.png -> Faux
# Déplacé : 106_F_CR1.png -> Faux
# Déplacé : 022_O_JC1.jpg -> Ori
# Fichier ignoré (classe inconnue) : 126_B.png
# Déplacé : 022_O_IB1.png -> Ori
# Déplacé : 174_F_CA1.png -> Faux
# Déplacé : 129_O_CA2.png -> Ori
# Déplacé : 195_F_JC8.jpg -> Faux
# Déplacé : 175_O_JC5.jpg -> Ori
# Déplacé : 038_O_BC1.png -> Ori
# Déplacé : 110_O_JC3.jpg -> Ori
# Déplacé : 164_O_CA1.png -> Ori
# Déplacé : 182_O_CA3.png -> Ori
# Déplacé : 128_O_JC1.jpg -> Ori
# Fichier ignoré (classe inconnue) : 070_B.png
# Déplacé : 174_O_BC3.png -> Ori
# Déplacé : 025_F.png -> Faux
# Déplacé : 156_F_IB1.png -> Faux
# Déplacé : 148_F_BC2.png -> Faux
# Déplacé : 015_F_IB2.png -> Faux
# Déplacé : 139_F_JC3.jpg -> Faux
# Déplacé : 140_O_NA1.png -> Ori
# Déplacé : 049_F_JC5.jpg -> Faux
# Déplacé : 090_F_IB1.png -> Faux
# Déplacé : 081_O_JC7.jpg -> Ori
# Déplacé : 068_F_BC3.png -> Faux
# Déplacé : 145_O_CA3.png -> Ori
# Déplacé : 130_F_NA3.png -> Faux
# Déplacé : 114_O_CR3.png -> Ori
# Déplacé : 089_F_BC2.png -> Faux
# Déplacé : 140_O_JC3.jpg -> Ori
# Déplacé : 186_O_JC4.jpg -> Ori
# Déplacé : 021_O_JC2.jpg -> Ori
# Déplacé : 110_F_JC8.jpg -> Faux
# Déplacé : 102_O_BC1.png -> Ori
# Fichier ignoré (classe inconnue) : 186_B.png
# Déplacé : 004_F_CA2.png -> Faux
# Déplacé : 024_O_NA3.png -> Ori
# Déplacé : 086_F_CR3.png -> Faux
# Déplacé : 171_F_JC3.jpg -> Faux
# Déplacé : 064_F_CR1.png -> Faux
# Déplacé : 006_O_CA1.png -> Ori
# Déplacé : 050_F_NA3.png -> Faux
# Déplacé : 181_O_JC5.jpg -> Ori
# Déplacé : 064_F_JC5.jpg -> Faux
# Déplacé : 046_F.png -> Faux
# Déplacé : 027_F_CR1.png -> Faux
# Déplacé : 112_F_NA3.png -> Faux
# Déplacé : 177_O_JC6.jpg -> Ori
# Déplacé : 112_F_JC2.jpg -> Faux
# Déplacé : 064_F_IB2.png -> Faux
# Déplacé : 093_F_CR2.png -> Faux
# Déplacé : 077_F_CA1.png -> Faux
# Déplacé : 049_O_CR3.png -> Ori
# Déplacé : 146_F_JC1.jpg -> Faux
# Déplacé : 168_O_BC1.png -> Ori
# Déplacé : 069_F_IB1.png -> Faux
# Déplacé : 101_O_CA3.png -> Ori
# Déplacé : 088_F_IB2.png -> Faux
# Déplacé : 119_F_JC6.jpg -> Faux
# Déplacé : 100_F_CA2.png -> Faux
# Déplacé : 181_F_CR2.png -> Faux
# Déplacé : 182_O_CA2.png -> Ori
# Déplacé : 190_O_IB2.png -> Ori
# Déplacé : 154_O_JC8.jpg -> Ori
# Déplacé : 009_O_IB3.png -> Ori
# Déplacé : 039_F_BC2.png -> Faux
# Déplacé : 198_O_IB1.png -> Ori
# Déplacé : 019_O_JC9.jpg -> Ori
# Déplacé : 175_F_IB2.png -> Faux
# Déplacé : 131_O_BC1.png -> Ori
# Déplacé : 170_O_IB1.png -> Ori
# Déplacé : 090_O_JC7.jpg -> Ori
# Déplacé : 066_O_BC3.png -> Ori
# Déplacé : 004_O_JC4.jpg -> Ori
# Déplacé : 018_O_JC8.jpg -> Ori
# Déplacé : 032_F_CA3.png -> Faux
# Déplacé : 001_F.png -> Faux
# Déplacé : 004_O_JC5.jpg -> Ori
# Déplacé : 082_F_IB1.png -> Faux
# Déplacé : 160_O_JC9.jpg -> Ori
# Déplacé : 024_F_CR2.png -> Faux
# Déplacé : 172_O_IB1.png -> Ori
# Déplacé : 055_O_IB3.png -> Ori
# Déplacé : 126_F_BC3.png -> Faux
# Déplacé : 133_O_CR2.png -> Ori
# Déplacé : 199_O_CR2.png -> Ori
# Déplacé : 080_F_JC1.jpg -> Faux
# Déplacé : 087_O_JC8.jpg -> Ori
# Déplacé : 058_F_JC5.jpg -> Faux
# Déplacé : 041_O_BC3.png -> Ori
# Déplacé : 197_O_JC6.jpg -> Ori
# Déplacé : 164_F_JC9.jpg -> Faux
# Déplacé : 172_F_JC9.jpg -> Faux
# Déplacé : 029_F_NA3.png -> Faux
# Déplacé : 130_O_CR3.png -> Ori
# Déplacé : 132_F_JC9.jpg -> Faux
# Déplacé : 157_F_BC1.png -> Faux
# Déplacé : 163_F_IB3.png -> Faux
# Déplacé : 085_O_CR2.png -> Ori
# Déplacé : 047_O_BC1.png -> Ori
# Déplacé : 038_F_JC9.jpg -> Faux
# Déplacé : 191_O_BC3.png -> Ori
# Déplacé : 118_O_BC1.png -> Ori
# Déplacé : 184_F_IB3.png -> Faux
# Déplacé : 192_O_CR1.png -> Ori
# Déplacé : 040_F_JC4.jpg -> Faux
# Déplacé : 129_O.png -> Ori
# Déplacé : 026_O_NA3.png -> Ori
# Déplacé : 069_O_IB2.png -> Ori
# Déplacé : 124_F_JC3.jpg -> Faux
# Déplacé : 099_F_JC8.jpg -> Faux
# Déplacé : 038_F_CA2.png -> Faux
# Déplacé : 005_F_NA2.png -> Faux
# Déplacé : 053_F_JC8.jpg -> Faux
# Déplacé : 128_F_IB3.png -> Faux
# Déplacé : 131_F_CA2.png -> Faux
# Déplacé : 061_O_NA3.png -> Ori
# Déplacé : 075_O_JC6.jpg -> Ori
# Déplacé : 100_O_CR1.png -> Ori
# Déplacé : 104_F_JC7.jpg -> Faux
# Déplacé : 081_O_JC9.jpg -> Ori
# Déplacé : 010_F_IB2.png -> Faux
# Déplacé : 017_O_CA1.png -> Ori
# Déplacé : 085_F_JC5.jpg -> Faux
# Déplacé : 004_O_JC2.jpg -> Ori
# Déplacé : 034_O_NA1.png -> Ori
# Fichier ignoré (classe inconnue) : 142_M.png
# Déplacé : 079_F_JC5.jpg -> Faux
# Déplacé : 009_F_JC5.jpg -> Faux
# Déplacé : 165_O_JC2.jpg -> Ori
# Déplacé : 107_F_BC1.png -> Faux
# Déplacé : 037_F_BC3.png -> Faux
# Déplacé : 107_O_JC3.jpg -> Ori
# Déplacé : 057_O_BC1.png -> Ori
# Déplacé : 092_F_CA3.png -> Faux
# Déplacé : 169_O_CR2.png -> Ori
# Déplacé : 043_F_JC5.jpg -> Faux
# Déplacé : 054_F_NA2.png -> Faux
# Déplacé : 161_F_CR1.png -> Faux
# Déplacé : 076_F_BC1.png -> Faux
# Fichier ignoré (classe inconnue) : 150_M.png
# Déplacé : 034_F_BC3.png -> Faux
# Déplacé : 166_O_CR1.png -> Ori
# Déplacé : 084_F_CA2.png -> Faux
# Déplacé : 101_F_IB2.png -> Faux
# Déplacé : 020_O_CR2.png -> Ori
# Déplacé : 200_F_JC2.jpg -> Faux
# Déplacé : 046_F_CR3.png -> Faux
# Déplacé : 137_F_CR2.png -> Faux
# Fichier ignoré (classe inconnue) : 046_M.png
# Déplacé : 179_O_CR3.png -> Ori
# Déplacé : 021_F_JC6.jpg -> Faux
# Déplacé : 038_F_CA1.png -> Faux
# Déplacé : 118_O.png -> Ori
# Déplacé : 023_F_CR3.png -> Faux
# Déplacé : 097_O_JC1.jpg -> Ori
# Déplacé : 025_F_JC6.jpg -> Faux
# Déplacé : 177_F_CA1.png -> Faux
# Déplacé : 131_F_BC2.png -> Faux
# Déplacé : 094_O_JC5.jpg -> Ori
# Fichier ignoré (classe inconnue) : 098_B.png
# Déplacé : 101_F_JC8.jpg -> Faux
# Déplacé : 151_O_JC2.jpg -> Ori
# Déplacé : 129_F_BC3.png -> Faux
# Déplacé : 176_O_IB2.png -> Ori
# Déplacé : 107_F_JC7.jpg -> Faux
# Déplacé : 155_O_JC6.jpg -> Ori
# Déplacé : 033_F_CR2.png -> Faux
# Déplacé : 071_F_JC8.jpg -> Faux
# Déplacé : 141_F_CR1.png -> Faux
# Déplacé : 033_F_JC7.jpg -> Faux
# Fichier ignoré (classe inconnue) : 077_M.png
# Déplacé : 187_F_JC7.jpg -> Faux
# Déplacé : 032_O_JC9.jpg -> Ori
# Déplacé : 051_F_CA1.png -> Faux
# Déplacé : 134_O_CR2.png -> Ori
# Déplacé : 006_O_CR2.png -> Ori
# Déplacé : 177_O_JC8.jpg -> Ori
# Déplacé : 026_O_CR1.png -> Ori
# Déplacé : 011_O_CA1.png -> Ori
# Déplacé : 039_O_JC8.jpg -> Ori
# Déplacé : 188_F_JC1.jpg -> Faux
# Déplacé : 145_O_JC8.jpg -> Ori
# Déplacé : 096_F_JC5.jpg -> Faux
# Déplacé : 153_F_BC1.png -> Faux
# Déplacé : 038_O_NA1.png -> Ori
# Déplacé : 017_F_CR2.png -> Faux
# Déplacé : 094_F_CA2.png -> Faux
# Déplacé : 171_F_CR3.png -> Faux
# Fichier ignoré (classe inconnue) : 158_M.png
# Déplacé : 024_O_JC8.jpg -> Ori
# Déplacé : 183_O_JC1.jpg -> Ori
# Déplacé : 016_O_IB1.png -> Ori
# Déplacé : 159_F_IB3.png -> Faux
# Déplacé : 086_O_IB2.png -> Ori
# Fichier ignoré (classe inconnue) : 031_M.png
# Déplacé : 189_O_CR1.png -> Ori
# Déplacé : 035_F.png -> Faux
# Déplacé : 110_F_BC1.png -> Faux
# Déplacé : 078_O_JC8.jpg -> Ori
# Déplacé : 021_F_BC3.png -> Faux
# Déplacé : 054_F_JC9.jpg -> Faux
# Déplacé : 100_F_JC9.jpg -> Faux
# Déplacé : 175_O_JC7.jpg -> Ori
# Déplacé : 101_F_CA3.png -> Faux
# Déplacé : 063_O_JC5.jpg -> Ori
# Déplacé : 089_O_JC3.jpg -> Ori
# Déplacé : 185_F_CA1.png -> Faux
# Déplacé : 093_O_JC6.jpg -> Ori
# Déplacé : 096_F_IB2.png -> Faux
# Déplacé : 133_O_JC4.jpg -> Ori
# Déplacé : 154_F_JC4.jpg -> Faux
# Déplacé : 168_O_NA2.png -> Ori
# Déplacé : 024_O_JC3.jpg -> Ori
# Déplacé : 006_O_JC3.jpg -> Ori
# Déplacé : 057_O_BC2.png -> Ori
# Déplacé : 081_F_JC6.jpg -> Faux
# Déplacé : 146_O_CA1.png -> Ori
# Déplacé : 089_O_JC4.jpg -> Ori
# Déplacé : 097_F_JC6.jpg -> Faux
# Déplacé : 089_O.png -> Ori
# Déplacé : 176_F_IB1.png -> Faux
# Déplacé : 115_O_JC7.jpg -> Ori
# Déplacé : 048_F_CA3.png -> Faux
# Déplacé : 073_O_BC3.png -> Ori
# Déplacé : 167_O_NA1.png -> Ori
# Déplacé : 055_F_JC4.jpg -> Faux
# Déplacé : 061_F_NA2.png -> Faux
# Déplacé : 018_O_NA3.png -> Ori
# Déplacé : 063_O_JC8.jpg -> Ori
# Déplacé : 075_O_BC3.png -> Ori
# Déplacé : 180_O_JC6.jpg -> Ori
# Déplacé : 142_F_CA2.png -> Faux
# Déplacé : 089_F_NA2.png -> Faux
# Déplacé : 188_O.png -> Ori
# Déplacé : 072_O_NA2.png -> Ori
# Déplacé : 165_O_JC4.jpg -> Ori
# Déplacé : 077_F_IB1.png -> Faux
# Déplacé : 163_O_NA1.png -> Ori
# Déplacé : 100_O_JC4.jpg -> Ori
# Déplacé : 035_F_CA2.png -> Faux
# Déplacé : 104_O_JC2.jpg -> Ori
# Déplacé : 008_O_JC9.jpg -> Ori
# Déplacé : 184_F_NA3.png -> Faux
# Déplacé : 195_F_BC2.png -> Faux
# Déplacé : 087_F_IB3.png -> Faux
# Déplacé : 109_F_JC4.jpg -> Faux
# Déplacé : 129_O_JC8.jpg -> Ori
# Déplacé : 004_O_BC2.png -> Ori
# Déplacé : 115_F_JC9.jpg -> Faux
# Déplacé : 029_O_NA1.png -> Ori
# Déplacé : 119_O_JC5.jpg -> Ori
# Déplacé : 137_F_IB1.png -> Faux
# Déplacé : 116_O_IB3.png -> Ori
# Déplacé : 197_F_NA2.png -> Faux
# Déplacé : 080_F_NA1.png -> Faux
# Déplacé : 035_O_JC1.jpg -> Ori
# Déplacé : 042_F_JC6.jpg -> Faux
# Déplacé : 139_F_IB2.png -> Faux
# Déplacé : 200_O_NA2.png -> Ori
# Déplacé : 032_O_NA3.png -> Ori
# Fichier ignoré (classe inconnue) : 184_M.png
# Déplacé : 018_O_CR1.png -> Ori
# Déplacé : 145_F_JC8.jpg -> Faux
# Déplacé : 030_F_IB3.png -> Faux
# Déplacé : 030_O_CA1.png -> Ori
# Déplacé : 039_O_IB1.png -> Ori
# Déplacé : 113_O_NA2.png -> Ori
# Déplacé : 194_O_IB3.png -> Ori
# Déplacé : 183_O_CR3.png -> Ori
# Déplacé : 155_F_JC4.jpg -> Faux
# Déplacé : 187_O.png -> Ori
# Déplacé : 192_O_CR2.png -> Ori
# Déplacé : 106_F_JC8.jpg -> Faux
# Déplacé : 004_O_IB2.png -> Ori
# Déplacé : 179_O_NA2.png -> Ori
# Déplacé : 155_F_CR3.png -> Faux
# Déplacé : 141_O_JC3.jpg -> Ori
# Déplacé : 080_F_CA3.png -> Faux
# Déplacé : 081_O_NA2.png -> Ori
# Déplacé : 006_F_JC6.jpg -> Faux
# Déplacé : 093_F_JC7.jpg -> Faux
# Déplacé : 155_F_JC2.jpg -> Faux
# Déplacé : 136_O_JC9.jpg -> Ori
# Déplacé : 056_O_JC5.jpg -> Ori
# Déplacé : 021_O_JC6.jpg -> Ori
# Déplacé : 139_O_JC1.jpg -> Ori
# Déplacé : 148_F_JC9.jpg -> Faux
# Déplacé : 127_O_NA1.png -> Ori
# Déplacé : 090_O_NA2.png -> Ori
# Déplacé : 045_O_BC2.png -> Ori
# Déplacé : 172_O_NA3.png -> Ori
# Déplacé : 174_O_CA1.png -> Ori
# Fichier ignoré (classe inconnue) : 014_M.png
# Déplacé : 173_O_CA1.png -> Ori
# Déplacé : 185_F_JC9.jpg -> Faux
# Déplacé : 199_O_CA1.png -> Ori
# Déplacé : 113_F_IB1.png -> Faux
# Déplacé : 125_O_JC3.jpg -> Ori
# Déplacé : 165_F_CA1.png -> Faux
# Déplacé : 175_O_NA3.png -> Ori
# Fichier ignoré (classe inconnue) : 164_M.png
# Déplacé : 076_O_IB1.png -> Ori
# Déplacé : 015_F_JC8.jpg -> Faux
# Déplacé : 111_O_NA1.png -> Ori
# Déplacé : 111_F_CA2.png -> Faux
# Déplacé : 162_O_BC1.png -> Ori
# Déplacé : 013_O_JC7.jpg -> Ori
# Déplacé : 068_O_BC1.png -> Ori
# Déplacé : 071_O_JC4.jpg -> Ori
# Déplacé : 146_O_JC3.jpg -> Ori
# Déplacé : 020_O_NA2.png -> Ori
# Déplacé : 177_O_JC4.jpg -> Ori
# Déplacé : 083_O_JC5.jpg -> Ori
# Déplacé : 107_O_IB1.png -> Ori
# Déplacé : 097_F_JC7.jpg -> Faux
# Déplacé : 056_F_JC8.jpg -> Faux
# Déplacé : 154_O_CR3.png -> Ori
# Déplacé : 053_F_JC9.jpg -> Faux
# Déplacé : 134_F_JC4.jpg -> Faux
# Déplacé : 089_O_JC7.jpg -> Ori
# Déplacé : 185_F_CA2.png -> Faux
# Déplacé : 024_F_JC7.jpg -> Faux
# Déplacé : 037_F_NA1.png -> Faux
# Déplacé : 025_O_JC6.jpg -> Ori
# Déplacé : 012_O_BC2.png -> Ori
# Déplacé : 134_O_NA3.png -> Ori
# Déplacé : 186_O.png -> Ori
# Déplacé : 043_F_JC8.jpg -> Faux
# Déplacé : 085_F_JC8.jpg -> Faux
# Déplacé : 044_O_CA3.png -> Ori
# Déplacé : 042_F_JC1.jpg -> Faux
# Déplacé : 145_O_NA2.png -> Ori
# Déplacé : 188_O_BC2.png -> Ori
# Déplacé : 107_F_BC3.png -> Faux
# Déplacé : 142_F_JC4.jpg -> Faux
# Déplacé : 029_O_CA2.png -> Ori
# Déplacé : 028_F_JC4.jpg -> Faux
# Déplacé : 144_O_JC6.jpg -> Ori
# Déplacé : 073_F_JC5.jpg -> Faux
# Déplacé : 133_F_JC3.jpg -> Faux
# Déplacé : 095_F.png -> Faux
# Déplacé : 005_O_JC3.jpg -> Ori
# Déplacé : 034_F.png -> Faux
# Déplacé : 143_F_JC3.jpg -> Faux
# Déplacé : 139_F_JC1.jpg -> Faux
# Déplacé : 158_O_JC4.jpg -> Ori
# Déplacé : 121_O_JC1.jpg -> Ori
# Déplacé : 113_F_JC7.jpg -> Faux
# Fichier ignoré (classe inconnue) : 174_B.png
# Déplacé : 036_F_IB2.png -> Faux
# Déplacé : 158_O_IB3.png -> Ori
# Déplacé : 006_O_JC9.jpg -> Ori
# Déplacé : 073_F_CA2.png -> Faux
# Déplacé : 082_F.png -> Faux
# Déplacé : 124_O_JC5.jpg -> Ori
# Déplacé : 049_O_NA1.png -> Ori
# Déplacé : 171_F_NA1.png -> Faux
# Fichier ignoré (classe inconnue) : 159_B.png
# Déplacé : 070_O_JC7.jpg -> Ori
# Déplacé : 062_F_JC4.jpg -> Faux
# Déplacé : 151_F_JC6.jpg -> Faux
# Déplacé : 074_F_JC7.jpg -> Faux
# Déplacé : 152_O_BC2.png -> Ori
# Déplacé : 146_F_IB2.png -> Faux
# Déplacé : 070_F_CA3.png -> Faux
# Déplacé : 020_O_BC3.png -> Ori
# Déplacé : 075_F_JC6.jpg -> Faux
# Déplacé : 050_O_JC7.jpg -> Ori
# Déplacé : 172_F_JC6.jpg -> Faux
# Déplacé : 020_O_CA1.png -> Ori
# Déplacé : 074_F_IB3.png -> Faux
# Déplacé : 011_F_NA1.png -> Faux
# Déplacé : 015_F_JC2.jpg -> Faux
# Déplacé : 098_O_JC8.jpg -> Ori
# Déplacé : 053_F_IB2.png -> Faux
# Déplacé : 169_F_CR2.png -> Faux
# Déplacé : 136_F_IB3.png -> Faux
# Déplacé : 190_F_NA1.png -> Faux
# Déplacé : 158_F_NA2.png -> Faux
# Déplacé : 042_F_JC5.jpg -> Faux
# Déplacé : 021_O_IB2.png -> Ori
# Déplacé : 160_F_IB3.png -> Faux
# Déplacé : 165_F_JC5.jpg -> Faux
# Déplacé : 124_O_IB1.png -> Ori
# Déplacé : 063_O_JC2.jpg -> Ori
# Déplacé : 102_F_CR2.png -> Faux
# Déplacé : 108_O_NA2.png -> Ori
# Déplacé : 105_O_JC8.jpg -> Ori
# Déplacé : 184_F_JC7.jpg -> Faux
# Déplacé : 044_F_CR2.png -> Faux
# Déplacé : 031_F_JC2.jpg -> Faux
# Déplacé : 194_O_BC2.png -> Ori
# Déplacé : 048_F_JC4.jpg -> Faux
# Déplacé : 139_O_JC5.jpg -> Ori
# Fichier ignoré (classe inconnue) : 167_M.png
# Déplacé : 020_F_JC9.jpg -> Faux
# Déplacé : 099_O_JC3.jpg -> Ori
# Déplacé : 061_O_NA2.png -> Ori
# Déplacé : 075_F_IB2.png -> Faux
# Déplacé : 030_O_NA1.png -> Ori
# Déplacé : 043_F_JC1.jpg -> Faux
# Déplacé : 052_F_BC2.png -> Faux
# Déplacé : 048_O_NA2.png -> Ori
# Déplacé : 164_F_CR2.png -> Faux
# Déplacé : 120_F_CA1.png -> Faux
# Déplacé : 194_F_JC1.jpg -> Faux
# ...
# Déplacé : 017_O_IB3.png -> Ori
# Déplacé : 171_O_CA2.png -> Ori
# Déplacé : 063_F_JC1.jpg -> Faux
# Déplacé : 061_F_JC2.jpg -> Faux
# Déplacé : 065_O_JC3.jpg -> Ori
# Déplacé : 012_O_CA2.png -> Ori
# Déplacé : 144_F_JC8.jpg -> Faux
# Déplacé : 071_O_IB2.png -> Ori
# Déplacé : 151_O_JC3.jpg -> Ori
# Déplacé : 117_O_BC1.png -> Ori
# Déplacé : 065_O_IB2.png -> Ori
# Déplacé : 156_F_JC4.jpg -> Faux
# Déplacé : 092_O_JC6.jpg -> Ori
# Déplacé : 081_O.png -> Ori
# Déplacé : 118_F_BC2.png -> Faux
# Déplacé : 144_F.png -> Faux
# Déplacé : 009_F_JC8.jpg -> Faux
# Déplacé : 030_O_JC1.jpg -> Ori
# Déplacé : 123_F_CA2.png -> Faux
# Déplacé : 004_F_BC1.png -> Faux
# Déplacé : 010_F_JC9.jpg -> Faux
# Déplacé : 153_O_CR3.png -> Ori
# Déplacé : 112_O_BC1.png -> Ori
# Déplacé : 114_F_JC6.jpg -> Faux
# Déplacé : 049_O_JC8.jpg -> Ori
# Déplacé : 092_O.png -> Ori
# Déplacé : 081_F_JC7.jpg -> Faux
# Fichier ignoré (classe inconnue) : 022_B.png
# Déplacé : 123_O_JC3.jpg -> Ori
# Déplacé : 003_O_IB1.png -> Ori
# Déplacé : 088_O_CR2.png -> Ori
# Déplacé : 075_F_CR1.png -> Faux
# Déplacé : 106_F_NA2.png -> Faux
# Déplacé : 150_F_JC9.jpg -> Faux
# Déplacé : 054_O_CA1.png -> Ori
# Déplacé : 166_O_CA3.png -> Ori
# Déplacé : 086_O_BC2.png -> Ori
# Déplacé : 081_O_CA1.png -> Ori
# Déplacé : 044_F_JC4.jpg -> Faux
# Fichier ignoré (classe inconnue) : 108_M.png
# Déplacé : 069_O_JC2.jpg -> Ori
# Fichier ignoré (classe inconnue) : 092_B.png
# Déplacé : 140_F_BC1.png -> Faux
# Déplacé : 196_O_CR3.png -> Ori
# Déplacé : 117_F_BC3.png -> Faux
# Déplacé : 014_O_CR1.png -> Ori
# Déplacé : 011_O_JC8.jpg -> Ori
# Déplacé : 045_F_CR2.png -> Faux
# Déplacé : 059_O_BC1.png -> Ori
# Déplacé : 070_O_CA1.png -> Ori
# Déplacé : 189_F_JC8.jpg -> Faux
# Déplacé : 186_O_JC6.jpg -> Ori
# Déplacé : 136_O_NA3.png -> Ori
# Déplacé : 137_O_BC3.png -> Ori
# Déplacé : 092_F_CR1.png -> Faux
# Déplacé : 152_O_CA3.png -> Ori
# Déplacé : 178_O_CR3.png -> Ori
# Déplacé : 110_O_JC5.jpg -> Ori
# Déplacé : 058_F_CA2.png -> Faux
# Déplacé : 171_O_JC2.jpg -> Ori
# Déplacé : 119_F_IB3.png -> Faux
# Déplacé : 144_O_IB1.png -> Ori
# Déplacé : 182_F_CA1.png -> Faux
# Déplacé : 139_O_BC2.png -> Ori
# Déplacé : 064_O_JC2.jpg -> Ori
# Déplacé : 148_O_IB3.png -> Ori
# Déplacé : 042_F_JC9.jpg -> Faux
# Déplacé : 118_F_CR2.png -> Faux
# Déplacé : 138_O_JC5.jpg -> Ori
# Déplacé : 057_O_CA2.png -> Ori
# Déplacé : 072_F_CR2.png -> Faux
# Déplacé : 040_F_JC5.jpg -> Faux
# Déplacé : 133_O_CR1.png -> Ori
# Déplacé : 004_F_IB3.png -> Faux
# Déplacé : 092_F_JC2.jpg -> Faux
# Déplacé : 079_F_JC1.jpg -> Faux
# Déplacé : 147_F_CR1.png -> Faux
# Déplacé : 059_F_CA2.png -> Faux
# Déplacé : 039_F_JC1.jpg -> Faux
# Déplacé : 121_O_IB2.png -> Ori
# Déplacé : 164_O_IB2.png -> Ori
# Déplacé : 045_O_JC9.jpg -> Ori
# Déplacé : 164_F_JC8.jpg -> Faux
# Déplacé : 164_O_JC5.jpg -> Ori
# Fichier ignoré (classe inconnue) : 055_M.png
# Déplacé : 109_F_NA2.png -> Faux
# Déplacé : 036_O_NA1.png -> Ori
# Déplacé : 024_F_CR3.png -> Faux
# Déplacé : 183_F_IB1.png -> Faux
# Déplacé : 053_F_IB3.png -> Faux
# Déplacé : 155_O_IB1.png -> Ori
# Déplacé : 044_O_BC1.png -> Ori
# Déplacé : 046_O_JC9.jpg -> Ori
# Déplacé : 008_O_CA3.png -> Ori
# Déplacé : 171_O_BC3.png -> Ori
# Déplacé : 089_O_CA3.png -> Ori
# Déplacé : 150_F_JC3.jpg -> Faux
# Déplacé : 095_O_CR3.png -> Ori
# Déplacé : 051_O_NA2.png -> Ori
# Déplacé : 187_O_JC9.jpg -> Ori
# Déplacé : 092_O_CR1.png -> Ori
# Déplacé : 023_F_JC9.jpg -> Faux
# Déplacé : 097_F_BC3.png -> Faux
# Déplacé : 070_F_CR3.png -> Faux
# Déplacé : 087_F_JC2.jpg -> Faux
# Déplacé : 144_O_JC2.jpg -> Ori
# Déplacé : 156_O_CR1.png -> Ori
# Déplacé : 146_O_JC9.jpg -> Ori
# Déplacé : 009_O_JC9.jpg -> Ori
# Déplacé : 194_F_BC2.png -> Faux
# Déplacé : 154_F_CR1.png -> Faux
# Déplacé : 169_F_IB2.png -> Faux
# Déplacé : 051_F_JC5.jpg -> Faux
# Déplacé : 077_F_JC4.jpg -> Faux
# Déplacé : 058_O_NA3.png -> Ori
# Déplacé : 033_F_NA2.png -> Faux
# Déplacé : 041_O.png -> Ori
# Déplacé : 110_F_CA2.png -> Faux
# Fichier ignoré (classe inconnue) : 048_M.png
# Déplacé : 112_F_CA3.png -> Faux
# Déplacé : 021_F_CR1.png -> Faux
# Déplacé : 139_O_IB1.png -> Ori
# Déplacé : 057_F_IB2.png -> Faux
# Déplacé : 199_F_JC6.jpg -> Faux
# Déplacé : 198_O_JC7.jpg -> Ori
# Déplacé : 091_O_NA2.png -> Ori
# Déplacé : 111_F_JC6.jpg -> Faux
# Déplacé : 084_O_JC5.jpg -> Ori
# Déplacé : 049_F_IB1.png -> Faux
# Déplacé : 152_O_IB2.png -> Ori
# Déplacé : 125_O_IB1.png -> Ori
# Déplacé : 180_F_BC3.png -> Faux
# Déplacé : 047_O_JC6.jpg -> Ori
# Déplacé : 059_O_CR3.png -> Ori
# Déplacé : 139_O_CR1.png -> Ori
# Déplacé : 159_O_IB1.png -> Ori
# Déplacé : 123_O_CR2.png -> Ori
# Déplacé : 095_F_JC2.jpg -> Faux
# Déplacé : 189_O_NA3.png -> Ori
# Déplacé : 042_O_JC6.jpg -> Ori
# Déplacé : 191_F_IB3.png -> Faux
# Fichier ignoré (classe inconnue) : 085_M.png
# Déplacé : 128_F_JC4.jpg -> Faux
# Déplacé : 184_F_JC2.jpg -> Faux
# Déplacé : 004_F_JC8.jpg -> Faux
# Déplacé : 150_F_NA3.png -> Faux
# Déplacé : 007_F_CR1.png -> Faux
# Déplacé : 104_O_IB1.png -> Ori
# Déplacé : 066_O_JC3.jpg -> Ori
# Déplacé : 074_O_BC2.png -> Ori
# Déplacé : 136_O_JC6.jpg -> Ori
# Fichier ignoré (classe inconnue) : 118_M.png
# Fichier ignoré (classe inconnue) : 002_M.png
# Déplacé : 172_O_CA3.png -> Ori
# Déplacé : 090_O_IB3.png -> Ori
# Déplacé : 007_O_JC2.jpg -> Ori
# Déplacé : 152_O.png -> Ori
# Déplacé : 054_F_JC6.jpg -> Faux
# Déplacé : 007_O_JC8.jpg -> Ori
# Déplacé : 038_O_JC5.jpg -> Ori
# Déplacé : 195_O_BC1.png -> Ori
# Déplacé : 191_F_JC6.jpg -> Faux
# Déplacé : 030_O_NA2.png -> Ori
# Déplacé : 179_F_CA3.png -> Faux
# Déplacé : 106_F_JC6.jpg -> Faux
# Déplacé : 135_O_IB1.png -> Ori
# Déplacé : 062_O_JC6.jpg -> Ori
# Déplacé : 122_O_CA3.png -> Ori
# Déplacé : 160_O_BC3.png -> Ori
# Déplacé : 041_F_BC1.png -> Faux
# Déplacé : 105_O_NA2.png -> Ori
# Déplacé : 168_O_BC3.png -> Ori
# Déplacé : 092_F_JC4.jpg -> Faux
# Déplacé : 068_O_BC2.png -> Ori
# Déplacé : 164_F_CA3.png -> Faux
# Déplacé : 199_O_JC5.jpg -> Ori
# Déplacé : 118_O_IB1.png -> Ori
# Déplacé : 119_F_BC2.png -> Faux
# Déplacé : 188_F_CA1.png -> Faux
# Déplacé : 036_F_JC3.jpg -> Faux
# Déplacé : 197_F_CA1.png -> Faux
# Déplacé : 051_F_JC1.jpg -> Faux
# Déplacé : 192_O_JC9.jpg -> Ori
# Déplacé : 053_O_JC2.jpg -> Ori
# Déplacé : 196_F_JC8.jpg -> Faux
# Déplacé : 067_F_CR3.png -> Faux
# Déplacé : 186_F_JC8.jpg -> Faux
# Déplacé : 150_O_JC6.jpg -> Ori
# Déplacé : 085_O_NA3.png -> Ori
# Déplacé : 119_O_JC7.jpg -> Ori
# Déplacé : 157_O_JC4.jpg -> Ori
# Déplacé : 196_O_JC8.jpg -> Ori
# Déplacé : 122_O_IB3.png -> Ori
# Fichier ignoré (classe inconnue) : 135_B.png
# Déplacé : 119_O_CA1.png -> Ori
# Déplacé : 183_O_BC3.png -> Ori
# Déplacé : 046_F_NA2.png -> Faux
# Déplacé : 019_F_JC1.jpg -> Faux
# Déplacé : 093_F_JC1.jpg -> Faux
# Déplacé : 038_F_JC6.jpg -> Faux
# Déplacé : 181_F_NA1.png -> Faux
# Déplacé : 098_O_JC1.jpg -> Ori
# Fichier ignoré (classe inconnue) : 083_B.png
# Déplacé : 172_O.png -> Ori
# Déplacé : 162_F_IB3.png -> Faux
# Déplacé : 062_F_BC3.png -> Faux
# Déplacé : 138_O_NA3.png -> Ori
# Fichier ignoré (classe inconnue) : 103_M.png
# Déplacé : 021_O_CA2.png -> Ori
# Déplacé : 153_O_JC1.jpg -> Ori
# Déplacé : 068_F_CR1.png -> Faux
# Déplacé : 047_F_JC9.jpg -> Faux
# Déplacé : 017_F_NA3.png -> Faux
# Déplacé : 159_F_CA3.png -> Faux
# Déplacé : 108_O_JC7.jpg -> Ori
# Déplacé : 083_O_JC2.jpg -> Ori
# Déplacé : 031_O_BC2.png -> Ori
# Déplacé : 005_O_NA3.png -> Ori
# Déplacé : 116_F_CR2.png -> Faux
# Déplacé : 089_O_BC2.png -> Ori
# Déplacé : 066_F_JC1.jpg -> Faux
# Déplacé : 162_O_JC2.jpg -> Ori
# Déplacé : 021_F_NA2.png -> Faux
# Déplacé : 002_F_JC8.jpg -> Faux
# Déplacé : 071_F.png -> Faux
# Déplacé : 043_O_BC1.png -> Ori
# Déplacé : 041_F_JC8.jpg -> Faux
# Fichier ignoré (classe inconnue) : 156_B.png
# Déplacé : 194_O_NA1.png -> Ori
# Fichier ignoré (classe inconnue) : 123_B.png
# Déplacé : 125_F_JC6.jpg -> Faux
# Déplacé : 186_O_JC8.jpg -> Ori
# Déplacé : 002_O_BC1.png -> Ori
# Déplacé : 020_O_JC1.jpg -> Ori
# Déplacé : 039_O_BC2.png -> Ori
# Déplacé : 032_O_JC7.jpg -> Ori
# Déplacé : 061_O_BC1.png -> Ori
# Déplacé : 026_O_JC6.jpg -> Ori
# Déplacé : 179_F_BC3.png -> Faux
# Déplacé : 114_O_JC2.jpg -> Ori
# Déplacé : 043_O_IB3.png -> Ori
# Déplacé : 155_F_CA3.png -> Faux
# Déplacé : 088_O_IB3.png -> Ori
# Déplacé : 124_O_CA2.png -> Ori
# Déplacé : 198_F_JC9.jpg -> Faux
# Déplacé : 092_F_JC6.jpg -> Faux
# Déplacé : 129_O_JC7.jpg -> Ori
# Déplacé : 048_F_IB2.png -> Faux
# Déplacé : 100_F_IB2.png -> Faux
# Déplacé : 106_O_JC3.jpg -> Ori
# Déplacé : 182_O_BC1.png -> Ori
# Déplacé : 142_O_JC7.jpg -> Ori
# Déplacé : 123_O_JC4.jpg -> Ori
# Déplacé : 059_O_BC3.png -> Ori
# Déplacé : 179_F_BC1.png -> Faux
# Déplacé : 150_O.png -> Ori
# Déplacé : 097_O_JC3.jpg -> Ori
# Fichier ignoré (classe inconnue) : 037_B.png
# Déplacé : 081_F_JC9.jpg -> Faux
# Déplacé : 042_O_BC1.png -> Ori
# Fichier ignoré (classe inconnue) : 174_M.png
# Déplacé : 066_O_JC2.jpg -> Ori
# Déplacé : 158_O_CA3.png -> Ori
# Déplacé : 022_F_JC2.jpg -> Faux
# Déplacé : 136_F_JC2.jpg -> Faux
# Déplacé : 010_F_CA3.png -> Faux
# Déplacé : 021_O_JC5.jpg -> Ori
# Déplacé : 152_F_BC2.png -> Faux
# Déplacé : 063_F_JC6.jpg -> Faux
# Déplacé : 119_O_JC1.jpg -> Ori
# Déplacé : 016_F_IB1.png -> Faux
# Déplacé : 018_O_JC1.jpg -> Ori
# Déplacé : 034_O.png -> Ori
# Déplacé : 193_F_IB2.png -> Faux
# Déplacé : 117_O_CA1.png -> Ori
# Déplacé : 091_O_CR1.png -> Ori
# Déplacé : 200_F_CA1.png -> Faux
# Déplacé : 093_F_JC5.jpg -> Faux
# Déplacé : 133_O_IB2.png -> Ori
# Déplacé : 101_F_JC1.jpg -> Faux
# Déplacé : 012_F_JC5.jpg -> Faux
# Déplacé : 061_O_BC3.png -> Ori
# Déplacé : 144_F_BC2.png -> Faux
# Déplacé : 127_F_CR3.png -> Faux
# Déplacé : 045_F_JC8.jpg -> Faux
# Déplacé : 134_F_CA3.png -> Faux
# Déplacé : 108_O_JC5.jpg -> Ori
# Déplacé : 113_O_CR2.png -> Ori
# Déplacé : 162_O_IB1.png -> Ori
# Déplacé : 046_F_BC3.png -> Faux
# Déplacé : 150_O_CR1.png -> Ori
# Déplacé : 166_F_BC1.png -> Faux
# Déplacé : 120_O_NA3.png -> Ori
# Déplacé : 046_F_BC2.png -> Faux
# Déplacé : 149_O_IB2.png -> Ori
# Déplacé : 043_F_NA2.png -> Faux
# Déplacé : 199_F_JC3.jpg -> Faux
# Déplacé : 017_O_JC2.jpg -> Ori
# Déplacé : 004_F_CR1.png -> Faux
# Déplacé : 016_F_CR1.png -> Faux
# Déplacé : 061_F_BC3.png -> Faux
# Déplacé : 080_F_JC3.jpg -> Faux
# Déplacé : 102_O_JC9.jpg -> Ori
# Déplacé : 030_F_JC7.jpg -> Faux
# Déplacé : 166_O_JC2.jpg -> Ori
# Déplacé : 003_O_IB2.png -> Ori
# Déplacé : 147_F_JC3.jpg -> Faux
# Déplacé : 115_F_JC2.jpg -> Faux
# Déplacé : 129_O_JC4.jpg -> Ori
# Déplacé : 107_F_JC4.jpg -> Faux
# Déplacé : 128_F_NA2.png -> Faux
# Déplacé : 079_F_IB1.png -> Faux
# Fichier ignoré (classe inconnue) : 013_M.png
# Déplacé : 095_O_CA1.png -> Ori
# Fichier ignoré (classe inconnue) : 200_B.png
# Déplacé : 028_F_JC9.jpg -> Faux
# Déplacé : 080_O_JC3.jpg -> Ori
# Déplacé : 101_O_CR3.png -> Ori
# Déplacé : 043_F_IB3.png -> Faux
# Déplacé : 185_O_BC1.png -> Ori
# Déplacé : 088_O_NA2.png -> Ori
# Déplacé : 092_F_JC7.jpg -> Faux
# Déplacé : 127_O_JC2.jpg -> Ori
# Déplacé : 023_O.png -> Ori
# Déplacé : 051_F_JC2.jpg -> Faux
# Déplacé : 121_F_IB3.png -> Faux
# Déplacé : 077_O_IB3.png -> Ori
# Déplacé : 019_O_JC8.jpg -> Ori
# Déplacé : 035_O_IB1.png -> Ori
# Déplacé : 124_F_CR3.png -> Faux
# Déplacé : 008_F_CA2.png -> Faux
# Déplacé : 083_F_CR1.png -> Faux
# Déplacé : 084_O_JC8.jpg -> Ori
# Déplacé : 051_F_JC8.jpg -> Faux
# Déplacé : 168_O_CA3.png -> Ori
# Déplacé : 114_O_JC3.jpg -> Ori
# Déplacé : 128_O_IB2.png -> Ori
# Déplacé : 058_O_NA1.png -> Ori
# Déplacé : 127_F_JC8.jpg -> Faux
# Déplacé : 141_O_CR3.png -> Ori
# Déplacé : 081_O_IB2.png -> Ori
# Fichier ignoré (classe inconnue) : 049_M.png
# Déplacé : 011_F_IB2.png -> Faux
# Déplacé : 178_F.png -> Faux
# Déplacé : 039_O_BC1.png -> Ori
# Déplacé : 116_O_NA3.png -> Ori
# Déplacé : 167_O_JC8.jpg -> Ori
# Déplacé : 038_F_BC1.png -> Faux
# Déplacé : 184_O.png -> Ori
# Déplacé : 017_F_IB3.png -> Faux
# Déplacé : 176_O_CR3.png -> Ori
# Déplacé : 007_O_CR1.png -> Ori
# Déplacé : 092_O_JC7.jpg -> Ori
# Déplacé : 043_F_NA1.png -> Faux
# Déplacé : 194_F_JC3.jpg -> Faux
# Déplacé : 073_O_CA1.png -> Ori
# Déplacé : 019_F_BC3.png -> Faux
# Fichier ignoré (classe inconnue) : 012_M.png
# Déplacé : 132_F_JC4.jpg -> Faux
# Déplacé : 114_O_JC5.jpg -> Ori
# Déplacé : 079_O_BC2.png -> Ori
# Déplacé : 129_F_JC3.jpg -> Faux
# Déplacé : 096_O_IB3.png -> Ori
# Déplacé : 134_F_JC7.jpg -> Faux
# Déplacé : 005_F.png -> Faux
# Déplacé : 128_F_IB2.png -> Faux
# Déplacé : 091_O_IB1.png -> Ori
# Déplacé : 048_O_CR3.png -> Ori
# Déplacé : 053_O_NA3.png -> Ori
# Déplacé : 078_F_CA3.png -> Faux
# Déplacé : 006_O_JC1.jpg -> Ori
# Déplacé : 185_O_NA2.png -> Ori
# Déplacé : 020_O_BC1.png -> Ori
# Déplacé : 121_O_BC1.png -> Ori
# Déplacé : 057_F_JC3.jpg -> Faux
# Déplacé : 045_F_JC5.jpg -> Faux
# Déplacé : 052_O_BC3.png -> Ori
# Déplacé : 013_O_CA1.png -> Ori
# Déplacé : 007_F_JC9.jpg -> Faux
# Déplacé : 196_F_BC3.png -> Faux
# Déplacé : 038_O_JC6.jpg -> Ori
# Déplacé : 093_F_CA1.png -> Faux
# Déplacé : 096_O_BC1.png -> Ori
# Déplacé : 127_F_JC3.jpg -> Faux
# Déplacé : 145_O_BC2.png -> Ori
# Déplacé : 138_O_JC8.jpg -> Ori
# Déplacé : 161_F_BC2.png -> Faux
# Déplacé : 076_O_CR1.png -> Ori
# Déplacé : 055_O_JC3.jpg -> Ori
# Déplacé : 090_O_BC3.png -> Ori
# Déplacé : 007_O_JC7.jpg -> Ori
# Déplacé : 049_F_IB2.png -> Faux
# Déplacé : 105_O.png -> Ori
# Déplacé : 173_F_JC9.jpg -> Faux
# Déplacé : 125_F_CA3.png -> Faux
# Déplacé : 147_F_IB3.png -> Faux
# Déplacé : 061_F_JC4.jpg -> Faux
# Déplacé : 068_F_BC2.png -> Faux
# Déplacé : 200_O_NA3.png -> Ori
# Déplacé : 190_F_JC6.jpg -> Faux
# Fichier ignoré (classe inconnue) : 057_M.png
# Déplacé : 195_O_NA1.png -> Ori
# Déplacé : 154_O_BC3.png -> Ori
# Déplacé : 127_O_JC8.jpg -> Ori
# Déplacé : 079_O_BC1.png -> Ori
# Déplacé : 077_F_JC5.jpg -> Faux
# Déplacé : 175_O_JC2.jpg -> Ori
# Fichier ignoré (classe inconnue) : 021_B.png
# Déplacé : 011_O_JC6.jpg -> Ori
# Déplacé : 140_F_BC3.png -> Faux
# Déplacé : 038_F_NA3.png -> Faux
# Déplacé : 121_O_JC9.jpg -> Ori
# Déplacé : 168_O_CR2.png -> Ori
# Déplacé : 103_F.png -> Faux
# Déplacé : 097_F.png -> Faux
# Déplacé : 179_O_CR1.png -> Ori
# Fichier ignoré (classe inconnue) : 018_M.png
# Déplacé : 195_O_JC7.jpg -> Ori
# Déplacé : 078_O_JC9.jpg -> Ori
# Déplacé : 010_F_JC5.jpg -> Faux
# Déplacé : 099_O_CA1.png -> Ori
# Déplacé : 069_O.png -> Ori
# Déplacé : 181_O_IB2.png -> Ori
# Déplacé : 155_O_CR1.png -> Ori
# Déplacé : 145_O_JC2.jpg -> Ori
# Déplacé : 097_F_JC9.jpg -> Faux
# Déplacé : 072_O_IB1.png -> Ori
# Déplacé : 106_O.png -> Ori
# Déplacé : 101_F_JC4.jpg -> Faux
# Déplacé : 058_O.png -> Ori
# Déplacé : 037_O_NA3.png -> Ori
# Déplacé : 176_O_JC9.jpg -> Ori
# Déplacé : 182_F_NA1.png -> Faux
# Déplacé : 185_F_NA3.png -> Faux
# Déplacé : 100_F_CA3.png -> Faux
# Déplacé : 091_O.png -> Ori
# Déplacé : 014_F_JC9.jpg -> Faux
# Déplacé : 084_F_IB3.png -> Faux
# Déplacé : 140_O_JC8.jpg -> Ori
# Déplacé : 070_F_JC6.jpg -> Faux
# Fichier ignoré (classe inconnue) : 157_M.png
# Déplacé : 091_O_CR2.png -> Ori
# Fichier ignoré (classe inconnue) : 183_B.png
# Déplacé : 023_O_JC8.jpg -> Ori
# Déplacé : 023_F_IB2.png -> Faux
# Déplacé : 188_O_JC1.jpg -> Ori
# Déplacé : 184_O_JC7.jpg -> Ori
# Déplacé : 132_O.png -> Ori
# Déplacé : 083_F_IB3.png -> Faux
# Déplacé : 025_O_NA1.png -> Ori
# Déplacé : 081_O_JC2.jpg -> Ori
# Déplacé : 170_F_BC1.png -> Faux
# Déplacé : 031_F_BC3.png -> Faux
# Déplacé : 029_O_JC7.jpg -> Ori
# Déplacé : 123_O_JC6.jpg -> Ori
# Déplacé : 003_O_CR1.png -> Ori
# Déplacé : 035_O_CA1.png -> Ori
# Déplacé : 183_F_JC4.jpg -> Faux
# Déplacé : 076_F_BC3.png -> Faux
# Déplacé : 120_F_CA2.png -> Faux
# Déplacé : 127_F_BC2.png -> Faux
# Déplacé : 178_F_CR2.png -> Faux
# Déplacé : 096_O_JC9.jpg -> Ori
# Déplacé : 075_O_CR1.png -> Ori
# Déplacé : 168_F_CR3.png -> Faux
# Fichier ignoré (classe inconnue) : 182_M.png
# Déplacé : 044_O.png -> Ori
# Déplacé : 072_F_CA3.png -> Faux
# Déplacé : 184_F_IB1.png -> Faux
# Fichier ignoré (classe inconnue) : 054_B.png
# Fichier ignoré (classe inconnue) : psnr.txt
# Déplacé : 130_F_BC1.png -> Faux
# Déplacé : 067_O_JC9.jpg -> Ori
# Déplacé : 082_F_CR1.png -> Faux
# Déplacé : 089_O_IB1.png -> Ori
# Fichier ignoré (classe inconnue) : 074_B.png
# Déplacé : 137_O_IB3.png -> Ori
# Déplacé : 157_F_CA2.png -> Faux
# Déplacé : 043_F_CA2.png -> Faux
# Déplacé : 112_O_NA2.png -> Ori
# Déplacé : 027_F_JC3.jpg -> Faux
# Déplacé : 140_O_BC3.png -> Ori
# Déplacé : 128_F_JC1.jpg -> Faux
# Déplacé : 071_O_JC7.jpg -> Ori
# Déplacé : 147_O_BC1.png -> Ori
# Déplacé : 180_O_CR3.png -> Ori
# Déplacé : 186_F_BC2.png -> Faux
# Déplacé : 084_F_JC6.jpg -> Faux
# Déplacé : 166_F_CA3.png -> Faux
# Déplacé : 053_F_JC4.jpg -> Faux
# Déplacé : 120_F_NA2.png -> Faux
# Déplacé : 127_O_CA2.png -> Ori
# Déplacé : 006_F.png -> Faux
# Déplacé : 035_O_CR2.png -> Ori
# Déplacé : 077_F_CR2.png -> Faux
# Déplacé : 163_F_CA1.png -> Faux
# Déplacé : 029_O_IB2.png -> Ori
# Déplacé : 100_O_CR3.png -> Ori
# Déplacé : 146_O_JC8.jpg -> Ori

# %%
# Lancer l'évaluation
if __name__ == "__main__":
    # Répertoire du dataset CoMoFoD
    authentic_dir = comoFqPath+"/Ori"  # Changez ce chemin
    forgery_dir = comoFqPath+"/Faux"  # Changez ce chemin

    # Évaluer les deux méthodes
    true_labels, cnn_predictions, traditional_predictions = evaluate_methods(authentic_dir, forgery_dir)

    # Générer des graphiques et analyser les résultats
    cnn_scores = [score if score is not None else 0.0 for score in cnn_predictions]
    generate_graphs(true_labels, cnn_predictions, cnn_scores, traditional_predictions)

    print("Évaluation terminée.")
# Out:
# Authenticate files: 5000
# Forgery files: 5000
# Error in CNN for /root/.cache/kagglehub/datasets/tusharchauhan1898/comofod/versions/1/CoMoFoD_small_v2/Ori/015_O_JC6.jpg: Modèle CNN non chargé.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-947d53a70eb7> in <cell line: 0>()
#       6
#       7     # Évaluer les deux méthodes
# ----> 8     true_labels, cnn_predictions, traditional_predictions = evaluate_methods(authentic_dir, forgery_dir)
#       9
#      10     # Générer des graphiques et analyser les résultats
#
# <ipython-input-6-7c1ddef157c6> in evaluate_methods(authentic_dir, forgery_dir)
#      34
#      35         # Traditional method
# ---> 36         traditional_forged = detect_forgery(image_path)
#      37
#      38         # Save results
#
# <ipython-input-4-99a5a5215bf2> in detect_forgery(image_path, rows, cols, similarity_threshold, forgery_threshold)
#      19
#      20             block = image[y_start:y_end, x_start:x_end]
# ---> 21             result = match_template(image, block)
#      22             locations = np.where(result >= similarity_threshold)
#      23
#
# /usr/local/lib/python3.11/dist-packages/skimage/feature/template.py in match_template(image, template, pad_input, mode, constant_values)
#     151
#     152     if image.ndim == 2:
# --> 153         xcorr = fftconvolve(image, template[::-1, ::-1], mode="valid")[1:-1, 1:-1]
#     154     elif image.ndim == 3:
#     155         xcorr = fftconvolve(image, template[::-1, ::-1, ::-1], mode="valid")[
#
# /usr/local/lib/python3.11/dist-packages/scipy/signal/_signaltools.py in fftconvolve(in1, in2, mode, axes)
#     669              for i in range(in1.ndim)]
#     670
# --> 671     ret = _freq_domain_conv(in1, in2, axes, shape, calc_fast_len=True)
#     672
#     673     return _apply_conv_mode(ret, s1, s2, mode, axes)
#
# /usr/local/lib/python3.11/dist-packages/scipy/signal/_signaltools.py in _freq_domain_conv(in1, in2, axes, shape, calc_fast_len)
#     509     sp2 = fft(in2, fshape, axes=axes)
#     510
# --> 511     ret = ifft(sp1 * sp2, fshape, axes=axes)
#     512
#     513     if calc_fast_len:
#
# /usr/local/lib/python3.11/dist-packages/scipy/fft/_backend.py in __ua_function__(method, args, kwargs)
#      26         if fn is None:
#      27             return NotImplemented
# ---> 28         return fn(*args, **kwargs)
#      29
#      30
#
# /usr/local/lib/python3.11/dist-packages/scipy/fft/_basic_backend.py in irfftn(x, s, axes, norm, overwrite_x, workers, plan)
#     128 def irfftn(x, s=None, axes=None, norm=None,
#     129            overwrite_x=False, workers=None, *, plan=None):
# --> 130     return _execute_nD('irfftn', _pocketfft.irfftn, x, s=s, axes=axes, norm=norm,
#     131                        overwrite_x=overwrite_x, workers=workers, plan=plan)
#     132
#
# /usr/local/lib/python3.11/dist-packages/scipy/fft/_basic_backend.py in _execute_nD(func_str, pocketfft_func, x, s, axes, norm, overwrite_x, workers, plan)
#      43
#      44     if is_numpy(xp):
# ---> 45         return pocketfft_func(x, s=s, axes=axes, norm=norm,
#      46                               overwrite_x=overwrite_x, workers=workers, plan=plan)
#      47
#
# /usr/local/lib/python3.11/dist-packages/scipy/fft/_pocketfft/basic.py in c2rn(forward, x, s, axes, norm, overwrite_x, workers, plan)
#     216
#     217     # Note: overwrite_x is not utilized
# --> 218     return pfft.c2r(tmp, axes, lastsize, forward, norm, None, workers)
#     219
#     220
#
# KeyboardInterrupt:
